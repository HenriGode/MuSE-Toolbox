# %%
from pathlib import Path
resultsdirs = {
    "OracleSAD": Path("/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle"),
    # "OracleSAD": Path("/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/Klaus_PALD_3D_1/oracle"),
    "COSAD": Path("/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD"),
    # "COSAD": Path("/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/STFT_16000_1024_256/PrecomputedSAD"),
    # "COSAD": Path("/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/Klaus_PALD_3D_1/PrecomputedSAD"),
}

# %%
# The first step is to load all csv files in resultsdir and concatenate them into a single dataframe
# important: every method has its own csv file and the method name is part of the filename but not the content
# I provide a list of the method names to load
method_names_long = [
  # "online-cgmm-mvdr",
  "BlockOnlineGSS_bl4_pc300",
  "RTF_Estimator_C",
  "RTF_Estimator_CSn",
  "RTF_Estimator_CWn",
  "RTF_Estimator_CSv",
  "RTF_Estimator_CWv",
  "RTF_Estimator_BOP", 
  "RTF_Estimator_BOP_S", 
  "RTF_Estimator_BOP_W", 
  "RTF_Estimator_BOPO", 
  "RTF_Estimator_BOPO_S", 
  "RTF_Estimator_BOPO_W",
  "RTF_Estimator_CB",
  "RTF_Estimator_CB_S",
  "RTF_Estimator_CB_W",
  "RTF_Estimator_CBW",
  "RTF_Estimator_Oracle", 
]
method_names_short = [
  # "online-cgmm-mvdr",
  "GSS",
  "C",
  "CSn",
  "CWn",
  "CSu",
  "CWu",
  "BOP", 
  "BOP-S", 
  "BOP-W", 
  "BOPO", 
  "BOPO-S", 
  "BOPO-W",
  "CB",
  "CB-S",
  "CW-B",#"CB-W",
  "CBW",
  "Oracle", 
]

# %%
# Now load the csv files and concatenate them into a single dataframe
import pandas as pd
dfs = {}
for key, resultsdir in resultsdirs.items():
    df_list = []
    for method_short, method_long in zip(method_names_short, method_names_long):
        csv_file = resultsdir / f"{method_long}_results.csv"
        if csv_file.exists():
            # note that the first colum is the scenario_id which should be the index of the df
            df = pd.read_csv(csv_file, index_col=0)
            df["method"] = method_short  # add a column for the method name
            # Append method name to index to ensure uniqueness across the combined dataframe
            df.index = df.index.astype(str) + "_" + method_short
            if method_short == "GSS": # for all columns which have 'SMVDR' in their name make copies of these columns for which the SMVDR is replaced with each of ['MVDR', 'LCMV', 'MPDR', 'LCMP', 'MPDR2', 'LCMP2']
                smvdr_columns = [col for col in df.columns if "SMVDR" in col]
                for col in smvdr_columns:
                    for bf in ['MVDR', 'LCMV', 'MPDR', 'LCMP', 'MPDR2', 'LCMP2']:
                        new_col = col.replace("SMVDR", bf)
                        df[new_col] = df[col]
                
            df_list.append(df)
        else:
            print(f"Warning: {csv_file} does not exist and will be skipped.")
    # Concatenate all dataframes
    df_all = pd.concat(df_list)
    print("Combined dataframe shape:", df_all.shape)
    # print an overview of all columns
    print("Columns in the combined dataframe:", df_all.columns)
    # For all columns with MHA in their name, they are Hermitian Angle metrics up to now in radians,
    # convert them to degrees for better interpretability
    mha_columns = [col for col in df_all.columns if "MHA" in col]
    for col in mha_columns:
        df_all[col] = df_all[col] * (180.0 / 3.141592653589793)  # radians to degrees
    dfs[key] = df_all
# Out:
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/BlockOnlineGSS_bl4_pc300_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_C_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_CSn_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_CWn_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_CSv_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_BOP_S_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_BOP_W_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_BOPO_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/RTF_Estimator_BOPO_S_results.csv does not exist and will be skipped.
# Combined dataframe shape: (21120, 357)
# Columns in the combined dataframe: Index(['MHA', 'WMHA', 'MHA_A1', 'WMHA_A1', 'MHA_A2', 'WMHA_A2', 'MHA_A3',
#        'WMHA_A3', 'MHA_D1', 'WMHA_D1',
#        ...
#        'SISDRo_LCMV_D1', 'DSISDR_LCMV_D1', 'SISDRo_MVDR_D1', 'DSISDR_MVDR_D1',
#        'SISDRi_D2', 'SISDRo_LCMV_D2', 'DSISDR_LCMV_D2', 'SISDRo_MVDR_D2',
#        'DSISDR_MVDR_D2', 'method'],
#       dtype='object', length=357)
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/BlockOnlineGSS_bl4_pc300_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_C_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_CSn_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_CWn_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_CSv_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_BOP_S_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_BOP_W_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_BOPO_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_BOPO_S_results.csv does not exist and will be skipped.
# Warning: /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/RTF_Estimator_Oracle_results.csv does not exist and will be skipped.
# Combined dataframe shape: (18480, 357)
# Columns in the combined dataframe: Index(['MHA', 'WMHA', 'MHA_A1', 'WMHA_A1', 'MHA_A2', 'WMHA_A2', 'MHA_A3',
#        'WMHA_A3', 'MHA_D1', 'WMHA_D1',
#        ...
#        'SISDRo_LCMV_D1', 'DSISDR_LCMV_D1', 'SISDRo_MVDR_D1', 'DSISDR_MVDR_D1',
#        'SISDRi_D2', 'SISDRo_LCMV_D2', 'DSISDR_LCMV_D2', 'SISDRo_MVDR_D2',
#        'DSISDR_MVDR_D2', 'method'],
#       dtype='object', length=357)

# %%
df_all
# Out:
#                                                   MHA       WMHA     MHA_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       20.142622   9.160703  30.641929
# J2_BXLS_main_exp_test_generator_1_CWu       15.440906  12.549106  11.305831
# J2_BXLS_main_exp_test_generator_10_CWu      17.993915  12.815616  30.939148
# J2_BXLS_main_exp_test_generator_100_CWu     13.049317   9.811066   8.933203
# J2_BXLS_main_exp_test_generator_1000_CWu     7.564665   6.597792  10.696505
# ...                                               ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle   0.001301   0.001605   0.001315
# J2_BXLS_main_exp_test_generator_996_Oracle   0.001325   0.001256   0.001057
# J2_BXLS_main_exp_test_generator_997_Oracle   0.001447   0.001179   0.002739
# J2_BXLS_main_exp_test_generator_998_Oracle   0.001255   0.001710   0.001322
# J2_BXLS_main_exp_test_generator_999_Oracle   0.000859   0.000979   0.001824
#
#                                               WMHA_A1     MHA_A2    WMHA_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        9.295654  17.518921  14.898000
# J2_BXLS_main_exp_test_generator_1_CWu       12.584913  21.912773  10.834587
# J2_BXLS_main_exp_test_generator_10_CWu      23.488643  24.756412  14.662053
# J2_BXLS_main_exp_test_generator_100_CWu      7.612252  29.298383  13.362666
# J2_BXLS_main_exp_test_generator_1000_CWu     7.922991  17.177017  14.905892
# ...                                               ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle   0.002908   0.002079   0.001903
# J2_BXLS_main_exp_test_generator_996_Oracle   0.001469   0.002079   0.000299
# J2_BXLS_main_exp_test_generator_997_Oracle   0.002354   0.002490   0.001319
# J2_BXLS_main_exp_test_generator_998_Oracle   0.000869   0.001995   0.003747
# J2_BXLS_main_exp_test_generator_999_Oracle   0.003806   0.001602   0.001022
#
#                                                MHA_A3    WMHA_A3  MHA_D1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       30.695765  11.245991     NaN
# J2_BXLS_main_exp_test_generator_1_CWu       23.718981  21.584429     NaN
# J2_BXLS_main_exp_test_generator_10_CWu      22.674162  19.370165     NaN
# J2_BXLS_main_exp_test_generator_100_CWu     16.843757  14.368891     NaN
# J2_BXLS_main_exp_test_generator_1000_CWu    17.512755  16.249650     NaN
# ...                                               ...        ...     ...
# J2_BXLS_main_exp_test_generator_995_Oracle   0.001985   0.001936     NaN
# J2_BXLS_main_exp_test_generator_996_Oracle   0.002494   0.002721     NaN
# J2_BXLS_main_exp_test_generator_997_Oracle   0.001386   0.001952     NaN
# J2_BXLS_main_exp_test_generator_998_Oracle   0.002546   0.001842     NaN
# J2_BXLS_main_exp_test_generator_999_Oracle   0.001905   0.000877     NaN
#
#                                             WMHA_D1  MHA_D2  WMHA_D2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_1_CWu           NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_10_CWu          NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_100_CWu         NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_1000_CWu        NaN     NaN      NaN
# ...                                             ...     ...      ...
# J2_BXLS_main_exp_test_generator_995_Oracle      NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_996_Oracle      NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_997_Oracle      NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_998_Oracle      NaN     NaN      NaN
# J2_BXLS_main_exp_test_generator_999_Oracle      NaN     NaN      NaN
#
#                                                SINRi  SINRo_LCMV  DSINR_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu      -0.046990    2.088926    2.135916
# J2_BXLS_main_exp_test_generator_1_CWu      -1.001096    2.179118    3.180214
# J2_BXLS_main_exp_test_generator_10_CWu     -0.623490    2.149988    2.773478
# J2_BXLS_main_exp_test_generator_100_CWu     0.798089    2.765340    1.967251
# J2_BXLS_main_exp_test_generator_1000_CWu    0.977145    3.453658    2.476513
# ...                                              ...         ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle  1.027198    6.392047    5.364850
# J2_BXLS_main_exp_test_generator_996_Oracle -2.329535    6.533920    8.863455
# J2_BXLS_main_exp_test_generator_997_Oracle -1.355584    3.576304    4.931888
# J2_BXLS_main_exp_test_generator_998_Oracle  2.561109   14.593029   12.031919
# J2_BXLS_main_exp_test_generator_999_Oracle  2.202267    7.845921    5.643654
#
#                                             SINRo_MVDR  DSINR_MVDR      SIRi  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         1.197610    1.244601  0.369886
# J2_BXLS_main_exp_test_generator_1_CWu         1.409869    2.410965 -0.884504
# J2_BXLS_main_exp_test_generator_10_CWu        1.761621    2.385111 -0.329967
# J2_BXLS_main_exp_test_generator_100_CWu       2.948549    2.150460  0.990898
# J2_BXLS_main_exp_test_generator_1000_CWu      2.380655    1.403510  1.159082
# ...                                                ...         ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle    6.372836    5.345638  1.153217
# J2_BXLS_main_exp_test_generator_996_Oracle    2.282780    4.612315 -1.520465
# J2_BXLS_main_exp_test_generator_997_Oracle    2.293840    3.649425  2.909677
# J2_BXLS_main_exp_test_generator_998_Oracle    8.054151    5.493041  2.716946
# J2_BXLS_main_exp_test_generator_999_Oracle    4.252282    2.050015  4.318270
#
#                                             SIRo_LCMV  DSIR_LCMV  SIRo_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        2.636739   2.266853   1.405689
# J2_BXLS_main_exp_test_generator_1_CWu        2.362483   3.246987   1.462061
# J2_BXLS_main_exp_test_generator_10_CWu       2.448227   2.778194   1.925195
# J2_BXLS_main_exp_test_generator_100_CWu      2.971021   1.980123   3.026001
# J2_BXLS_main_exp_test_generator_1000_CWu     3.743756   2.584673   2.432816
# ...                                               ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle   6.483002   5.329784   6.455000
# J2_BXLS_main_exp_test_generator_996_Oracle   8.572778  10.093243   2.650250
# J2_BXLS_main_exp_test_generator_997_Oracle   9.809898   6.900222   3.959693
# J2_BXLS_main_exp_test_generator_998_Oracle  15.688646  12.971701   8.193966
# J2_BXLS_main_exp_test_generator_999_Oracle  11.420248   7.101978   4.902349
#
#                                             DSIR_MVDR       SNRi  SNRo_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        1.035803  10.158140  11.711730
# J2_BXLS_main_exp_test_generator_1_CWu        2.346565  15.067699  16.575583
# J2_BXLS_main_exp_test_generator_10_CWu       2.255162  11.355325  13.893476
# J2_BXLS_main_exp_test_generator_100_CWu      2.035103  14.754080  17.641479
# J2_BXLS_main_exp_test_generator_1000_CWu     1.273733  15.179076  17.292641
# ...                                               ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle   5.301783  16.871469  21.496847
# J2_BXLS_main_exp_test_generator_996_Oracle   4.170714   5.406623  10.732058
# J2_BXLS_main_exp_test_generator_997_Oracle   1.050017   0.806594   4.813566
# J2_BXLS_main_exp_test_generator_998_Oracle   5.477020  17.243204  21.249697
# J2_BXLS_main_exp_test_generator_999_Oracle   0.584079   6.482077  10.123583
#
#                                             DSNR_LCMV  SNRo_MVDR  DSNR_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        1.553590  15.193881   5.035741
# J2_BXLS_main_exp_test_generator_1_CWu        1.507883  20.926447   5.858747
# J2_BXLS_main_exp_test_generator_10_CWu       2.538151  16.760113   5.404788
# J2_BXLS_main_exp_test_generator_100_CWu      2.887400  21.614485   6.860405
# J2_BXLS_main_exp_test_generator_1000_CWu     2.113564  22.616856   7.437779
# ...                                               ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle   4.625378  24.142477   7.271008
# J2_BXLS_main_exp_test_generator_996_Oracle   5.325434  12.978354   7.571730
# J2_BXLS_main_exp_test_generator_997_Oracle   4.006971   7.431970   6.625376
# J2_BXLS_main_exp_test_generator_998_Oracle   4.006493  23.472000   6.228796
# J2_BXLS_main_exp_test_generator_999_Oracle   3.641506  12.822305   6.340228
#
#                                               HGSDRi  HGSDRo_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu      -0.046990     0.887914
# J2_BXLS_main_exp_test_generator_1_CWu      -1.001096     0.395327
# J2_BXLS_main_exp_test_generator_10_CWu     -0.623490     0.826381
# J2_BXLS_main_exp_test_generator_100_CWu     0.798089     1.197904
# J2_BXLS_main_exp_test_generator_1000_CWu    0.977145     1.564339
# ...                                              ...          ...
# J2_BXLS_main_exp_test_generator_995_Oracle  1.027198     5.038904
# J2_BXLS_main_exp_test_generator_996_Oracle -2.329535     4.608316
# J2_BXLS_main_exp_test_generator_997_Oracle -1.355584     2.360519
# J2_BXLS_main_exp_test_generator_998_Oracle  2.561109     9.467661
# J2_BXLS_main_exp_test_generator_999_Oracle  2.202267     5.874900
#
#                                             DHGSDR_LCMV  HGSDRo_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          0.934904     0.505938
# J2_BXLS_main_exp_test_generator_1_CWu          1.396424     0.178793
# J2_BXLS_main_exp_test_generator_10_CWu         1.449871     0.741001
# J2_BXLS_main_exp_test_generator_100_CWu        0.399815     1.620282
# J2_BXLS_main_exp_test_generator_1000_CWu       0.587194     1.296322
# ...                                                 ...          ...
# J2_BXLS_main_exp_test_generator_995_Oracle     4.011706     5.207686
# J2_BXLS_main_exp_test_generator_996_Oracle     6.937851     1.686838
# J2_BXLS_main_exp_test_generator_997_Oracle     3.716104     1.540300
# J2_BXLS_main_exp_test_generator_998_Oracle     6.906551     6.955691
# J2_BXLS_main_exp_test_generator_999_Oracle     3.672634     3.552696
#
#                                             DHGSDR_MVDR   Gt_LCMV   Gt_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          0.552928 -0.350926 -0.823079
# J2_BXLS_main_exp_test_generator_1_CWu          1.179889 -0.596645 -1.243147
# J2_BXLS_main_exp_test_generator_10_CWu         1.364491 -0.709230 -0.927736
# J2_BXLS_main_exp_test_generator_100_CWu        0.822193 -0.469236 -0.936102
# J2_BXLS_main_exp_test_generator_1000_CWu       0.319177 -0.572776 -1.003449
# ...                                                 ...       ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle     4.180488  0.046500 -0.030792
# J2_BXLS_main_exp_test_generator_996_Oracle     4.016373  0.183299  0.033018
# J2_BXLS_main_exp_test_generator_997_Oracle     2.895884 -0.065286 -0.198875
# J2_BXLS_main_exp_test_generator_998_Oracle     4.394582  0.125851 -0.024219
# J2_BXLS_main_exp_test_generator_999_Oracle     1.350430 -0.053032 -0.141223
#
#                                               Gi_LCMV   Gi_MVDR   Gn_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       -2.617779 -1.858882 -1.904515
# J2_BXLS_main_exp_test_generator_1_CWu       -3.843632 -3.589712 -2.104529
# J2_BXLS_main_exp_test_generator_10_CWu      -3.487423 -3.182898 -3.247380
# J2_BXLS_main_exp_test_generator_100_CWu     -2.449360 -2.971206 -3.356635
# J2_BXLS_main_exp_test_generator_1000_CWu    -3.157449 -2.277182 -2.686340
# ...                                               ...       ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle  -5.283284 -5.332574 -4.578876
# J2_BXLS_main_exp_test_generator_996_Oracle  -9.909944 -4.137697 -5.142136
# J2_BXLS_main_exp_test_generator_997_Oracle  -6.965508 -1.248891 -4.072258
# J2_BXLS_main_exp_test_generator_998_Oracle -12.845849 -5.501239 -3.880641
# J2_BXLS_main_exp_test_generator_999_Oracle  -7.155009 -0.725302 -3.694538
#
#                                              Gn_MVDR    Dt_LCMV    Dt_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu      -5.858819   8.076265   9.514871
# J2_BXLS_main_exp_test_generator_1_CWu      -7.101896   6.060128   7.529257
# J2_BXLS_main_exp_test_generator_10_CWu     -6.332522   7.492919   8.626047
# J2_BXLS_main_exp_test_generator_100_CWu    -7.796508   7.073931   7.953578
# J2_BXLS_main_exp_test_generator_1000_CWu   -8.441228   7.122314   9.151212
# ...                                              ...        ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle -7.301802  10.712364  11.509497
# J2_BXLS_main_exp_test_generator_996_Oracle -7.538712   8.851689  10.547258
# J2_BXLS_main_exp_test_generator_997_Oracle -6.824251   8.588607   9.541698
# J2_BXLS_main_exp_test_generator_998_Oracle -6.253014  10.965323  13.411247
# J2_BXLS_main_exp_test_generator_999_Oracle -6.481451  10.709635  11.747536
#
#                                              Di_LCMV   Di_MVDR   Dn_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       1.416714  3.717542  0.453627
# J2_BXLS_main_exp_test_generator_1_CWu       0.822172  2.947530 -0.339642
# J2_BXLS_main_exp_test_generator_10_CWu      2.042654  3.283547  0.573384
# J2_BXLS_main_exp_test_generator_100_CWu     0.295528  3.242200 -0.192124
# J2_BXLS_main_exp_test_generator_1000_CWu    1.400919  5.027041 -0.134817
# ...                                              ...       ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle -0.181481  1.490119  0.771142
# J2_BXLS_main_exp_test_generator_996_Oracle  0.510162  1.534805  0.969366
# J2_BXLS_main_exp_test_generator_997_Oracle  0.453123  0.287590  1.339815
# J2_BXLS_main_exp_test_generator_998_Oracle  0.790491  3.001668 -0.215262
# J2_BXLS_main_exp_test_generator_999_Oracle  0.659026  0.318843  0.224786
#
#                                              Dn_MVDR   SINRi_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       1.831040  10.221827
# J2_BXLS_main_exp_test_generator_1_CWu       1.334046  16.498886
# J2_BXLS_main_exp_test_generator_10_CWu      1.573067  12.147581
# J2_BXLS_main_exp_test_generator_100_CWu     1.005154  14.601089
# J2_BXLS_main_exp_test_generator_1000_CWu    1.144960  17.389168
# ...                                              ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle  1.159743  19.244274
# J2_BXLS_main_exp_test_generator_996_Oracle  1.212278   5.818176
# J2_BXLS_main_exp_test_generator_997_Oracle  1.329158   1.614096
# J2_BXLS_main_exp_test_generator_998_Oracle  1.467925  19.219728
# J2_BXLS_main_exp_test_generator_999_Oracle  1.429793   2.954298
#
#                                             SINRo_LCMV_A1  DSINR_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           15.374886       5.153059
# J2_BXLS_main_exp_test_generator_1_CWu           21.534958       5.036072
# J2_BXLS_main_exp_test_generator_10_CWu          16.652548       4.504967
# J2_BXLS_main_exp_test_generator_100_CWu         21.452824       6.851734
# J2_BXLS_main_exp_test_generator_1000_CWu        22.558100       5.168932
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle      25.517620       6.273346
# J2_BXLS_main_exp_test_generator_996_Oracle      12.555082       6.736906
# J2_BXLS_main_exp_test_generator_997_Oracle      10.096301       8.482205
# J2_BXLS_main_exp_test_generator_998_Oracle      23.902149       4.682421
# J2_BXLS_main_exp_test_generator_999_Oracle      11.696289       8.741991
#
#                                             SINRo_MVDR_A1  DSINR_MVDR_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           15.377674       5.155848
# J2_BXLS_main_exp_test_generator_1_CWu           21.538937       5.040051
# J2_BXLS_main_exp_test_generator_10_CWu          16.653297       4.505716
# J2_BXLS_main_exp_test_generator_100_CWu         21.457937       6.856848
# J2_BXLS_main_exp_test_generator_1000_CWu        23.823296       6.434128
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle      25.510925       6.266651
# J2_BXLS_main_exp_test_generator_996_Oracle      12.554879       6.736703
# J2_BXLS_main_exp_test_generator_997_Oracle      10.129333       8.515237
# J2_BXLS_main_exp_test_generator_998_Oracle      23.913935       4.694206
# J2_BXLS_main_exp_test_generator_999_Oracle      11.681650       8.727352
#
#                                               SIRi_A1  SIRo_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       45.914383     42.880383
# J2_BXLS_main_exp_test_generator_1_CWu       48.730232     50.963654
# J2_BXLS_main_exp_test_generator_10_CWu      40.417980     35.376949
# J2_BXLS_main_exp_test_generator_100_CWu     52.168842     44.827881
# J2_BXLS_main_exp_test_generator_1000_CWu    52.714176     28.571989
# ...                                               ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle  50.596333     41.493599
# J2_BXLS_main_exp_test_generator_996_Oracle  48.508190     50.334393
# J2_BXLS_main_exp_test_generator_997_Oracle  80.007774     53.718620
# J2_BXLS_main_exp_test_generator_998_Oracle  62.235855     45.809692
# J2_BXLS_main_exp_test_generator_999_Oracle  47.153099     48.774830
#
#                                             DSIR_LCMV_A1  SIRo_MVDR_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          -3.034000     42.865860
# J2_BXLS_main_exp_test_generator_1_CWu           2.233421     51.929733
# J2_BXLS_main_exp_test_generator_10_CWu         -5.041031     35.432789
# J2_BXLS_main_exp_test_generator_100_CWu        -7.340961     45.995735
# J2_BXLS_main_exp_test_generator_1000_CWu      -24.142187     38.166779
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     -9.102734     41.199112
# J2_BXLS_main_exp_test_generator_996_Oracle      1.826202     49.738575
# J2_BXLS_main_exp_test_generator_997_Oracle    -26.289154     52.878639
# J2_BXLS_main_exp_test_generator_998_Oracle    -16.426163     46.687294
# J2_BXLS_main_exp_test_generator_999_Oracle      1.621731     48.508476
#
#                                             DSIR_MVDR_A1    SNRi_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          -3.048523  10.223046
# J2_BXLS_main_exp_test_generator_1_CWu           3.199501  16.501507
# J2_BXLS_main_exp_test_generator_10_CWu         -4.985191  12.156998
# J2_BXLS_main_exp_test_generator_100_CWu        -6.173107  14.601250
# J2_BXLS_main_exp_test_generator_1000_CWu      -14.547398  17.395098
# ...                                                  ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle     -9.397221  19.248198
# J2_BXLS_main_exp_test_generator_996_Oracle      1.230385   5.818228
# J2_BXLS_main_exp_test_generator_997_Oracle    -27.129135   1.614099
# J2_BXLS_main_exp_test_generator_998_Oracle    -15.548561  19.220119
# J2_BXLS_main_exp_test_generator_999_Oracle      1.355377   2.954364
#
#                                             SNRo_LCMV_A1  DSNR_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          15.387683      5.164637
# J2_BXLS_main_exp_test_generator_1_CWu          21.541168      5.039661
# J2_BXLS_main_exp_test_generator_10_CWu         16.722811      4.565813
# J2_BXLS_main_exp_test_generator_100_CWu        21.475296      6.874046
# J2_BXLS_main_exp_test_generator_1000_CWu       24.029495      6.634398
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     25.616991      6.368793
# J2_BXLS_main_exp_test_generator_996_Oracle     12.556486      6.738258
# J2_BXLS_main_exp_test_generator_997_Oracle     10.093080      8.478981
# J2_BXLS_main_exp_test_generator_998_Oracle     23.932842      4.712723
# J2_BXLS_main_exp_test_generator_999_Oracle     11.696486      8.742123
#
#                                             SNRo_MVDR_A1  DSNR_MVDR_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          15.390283      5.167236
# J2_BXLS_main_exp_test_generator_1_CWu          21.543587      5.042080
# J2_BXLS_main_exp_test_generator_10_CWu         16.723928      4.566931
# J2_BXLS_main_exp_test_generator_100_CWu        21.476290      6.875040
# J2_BXLS_main_exp_test_generator_1000_CWu       24.060404      6.665306
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     25.617830      6.369633
# J2_BXLS_main_exp_test_generator_996_Oracle     12.556342      6.738114
# J2_BXLS_main_exp_test_generator_997_Oracle     10.125175      8.511077
# J2_BXLS_main_exp_test_generator_998_Oracle     23.940142      4.720022
# J2_BXLS_main_exp_test_generator_999_Oracle     11.681795      8.727431
#
#                                             HGSDRi_A1  HGSDRo_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       10.221827        6.365739
# J2_BXLS_main_exp_test_generator_1_CWu       16.498888        6.962545
# J2_BXLS_main_exp_test_generator_10_CWu      12.147581        8.679659
# J2_BXLS_main_exp_test_generator_100_CWu     14.601089        7.950378
# J2_BXLS_main_exp_test_generator_1000_CWu    17.389168        9.689209
# ...                                               ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle  19.244274       13.087543
# J2_BXLS_main_exp_test_generator_996_Oracle   5.818176        8.858844
# J2_BXLS_main_exp_test_generator_997_Oracle   1.614096        5.095202
# J2_BXLS_main_exp_test_generator_998_Oracle  19.219727       14.436064
# J2_BXLS_main_exp_test_generator_999_Oracle   2.954298        5.225915
#
#                                             DHGSDR_LCMV_A1  HGSDRo_MVDR_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            -3.856088        6.366740
# J2_BXLS_main_exp_test_generator_1_CWu            -9.536343        6.963488
# J2_BXLS_main_exp_test_generator_10_CWu           -3.467922        8.679776
# J2_BXLS_main_exp_test_generator_100_CWu          -6.650712        7.950871
# J2_BXLS_main_exp_test_generator_1000_CWu         -7.699959        9.709606
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle       -6.156731       13.082818
# J2_BXLS_main_exp_test_generator_996_Oracle        3.040668        8.858411
# J2_BXLS_main_exp_test_generator_997_Oracle        3.481107        5.051976
# J2_BXLS_main_exp_test_generator_998_Oracle       -4.783663       14.468069
# J2_BXLS_main_exp_test_generator_999_Oracle        2.271617        5.218222
#
#                                             DHGSDR_MVDR_A1  Gt_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            -3.855086   -1.185255
# J2_BXLS_main_exp_test_generator_1_CWu            -9.535400   -1.282117
# J2_BXLS_main_exp_test_generator_10_CWu           -3.467805   -0.739420
# J2_BXLS_main_exp_test_generator_100_CWu          -6.650218   -0.929520
# J2_BXLS_main_exp_test_generator_1000_CWu         -7.679562   -0.800418
# ...                                                    ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle       -6.161456    0.139742
# J2_BXLS_main_exp_test_generator_996_Oracle        3.040235    0.152996
# J2_BXLS_main_exp_test_generator_997_Oracle        3.437881   -1.163696
# J2_BXLS_main_exp_test_generator_998_Oracle       -4.751657   -0.111267
# J2_BXLS_main_exp_test_generator_999_Oracle        2.263924   -0.957892
#
#                                             Gt_MVDR_A1  Gi_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -1.184260    1.848749
# J2_BXLS_main_exp_test_generator_1_CWu        -1.281495   -3.515544
# J2_BXLS_main_exp_test_generator_10_CWu       -0.739420    4.301609
# J2_BXLS_main_exp_test_generator_100_CWu      -0.929020    6.411441
# J2_BXLS_main_exp_test_generator_1000_CWu     -0.786268   23.341768
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle    0.139886    9.242476
# J2_BXLS_main_exp_test_generator_996_Oracle    0.152981   -1.673210
# J2_BXLS_main_exp_test_generator_997_Oracle   -1.140973   25.125458
# J2_BXLS_main_exp_test_generator_998_Oracle   -0.104934   16.314899
# J2_BXLS_main_exp_test_generator_999_Oracle   -0.957286   -2.579618
#
#                                             Gi_MVDR_A1  Gn_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         1.864269   -6.349893
# J2_BXLS_main_exp_test_generator_1_CWu        -4.480999   -6.321776
# J2_BXLS_main_exp_test_generator_10_CWu        4.245770   -5.305233
# J2_BXLS_main_exp_test_generator_100_CWu       5.244089   -7.803568
# J2_BXLS_main_exp_test_generator_1000_CWu     13.761129   -7.434816
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle    9.537103   -6.229050
# J2_BXLS_main_exp_test_generator_996_Oracle   -1.077405   -6.585262
# J2_BXLS_main_exp_test_generator_997_Oracle   25.988161   -9.642678
# J2_BXLS_main_exp_test_generator_998_Oracle   15.443634   -4.823991
# J2_BXLS_main_exp_test_generator_999_Oracle   -2.312661   -9.700015
#
#                                             Gn_MVDR_A1  Dt_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -6.351497    8.093865
# J2_BXLS_main_exp_test_generator_1_CWu        -6.323571    8.413456
# J2_BXLS_main_exp_test_generator_10_CWu       -5.306352   10.230595
# J2_BXLS_main_exp_test_generator_100_CWu      -7.804060    9.066943
# J2_BXLS_main_exp_test_generator_1000_CWu     -7.451575   10.594995
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle   -6.229744   13.230163
# J2_BXLS_main_exp_test_generator_996_Oracle   -6.585133   11.060785
# J2_BXLS_main_exp_test_generator_997_Oracle   -9.652050    7.826010
# J2_BXLS_main_exp_test_generator_998_Oracle   -4.824956   15.054504
# J2_BXLS_main_exp_test_generator_999_Oracle   -9.684717    7.255988
#
#                                             Dt_MVDR_A1  Di_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         8.093981   -0.835499
# J2_BXLS_main_exp_test_generator_1_CWu         8.414546   -1.388023
# J2_BXLS_main_exp_test_generator_10_CWu       10.230589   -3.850673
# J2_BXLS_main_exp_test_generator_100_CWu       9.067329   -5.603326
# J2_BXLS_main_exp_test_generator_1000_CWu     10.617680  -23.313728
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle   13.227873   -8.560960
# J2_BXLS_main_exp_test_generator_996_Oracle   11.060455    8.021511
# J2_BXLS_main_exp_test_generator_997_Oracle    7.734195  -25.140610
# J2_BXLS_main_exp_test_generator_998_Oracle   15.084720  -16.183342
# J2_BXLS_main_exp_test_generator_999_Oracle    7.246830    2.900570
#
#                                             Di_MVDR_A1  Dn_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -0.907927    1.652084
# J2_BXLS_main_exp_test_generator_1_CWu        -1.150935    1.529895
# J2_BXLS_main_exp_test_generator_10_CWu       -3.879232    2.444501
# J2_BXLS_main_exp_test_generator_100_CWu      -4.361704    1.049426
# J2_BXLS_main_exp_test_generator_1000_CWu    -13.526019    1.362095
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle   -8.843566    1.544526
# J2_BXLS_main_exp_test_generator_996_Oracle    8.285320    1.389553
# J2_BXLS_main_exp_test_generator_997_Oracle  -25.994814    0.542654
# J2_BXLS_main_exp_test_generator_998_Oracle  -15.286991    2.227385
# J2_BXLS_main_exp_test_generator_999_Oracle    3.010156    0.597715
#
#                                             Dn_MVDR_A1  SINRi_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         1.650611  1.887603
# J2_BXLS_main_exp_test_generator_1_CWu         1.531565 -2.261957
# J2_BXLS_main_exp_test_generator_10_CWu        2.444927  2.300396
# J2_BXLS_main_exp_test_generator_100_CWu       1.049175  0.604880
# J2_BXLS_main_exp_test_generator_1000_CWu      1.368300  0.860084
# ...                                                ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle    1.544874 -3.111718
# J2_BXLS_main_exp_test_generator_996_Oracle    1.389686 -0.421035
# J2_BXLS_main_exp_test_generator_997_Oracle    0.541571 -1.222434
# J2_BXLS_main_exp_test_generator_998_Oracle    2.226692  1.811572
# J2_BXLS_main_exp_test_generator_999_Oracle    0.596464  4.036656
#
#                                             SINRo_LCMV_A2  DSINR_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            7.286916       5.399313
# J2_BXLS_main_exp_test_generator_1_CWu            5.077813       7.339770
# J2_BXLS_main_exp_test_generator_10_CWu           4.875190       2.574794
# J2_BXLS_main_exp_test_generator_100_CWu          5.009007       4.404126
# J2_BXLS_main_exp_test_generator_1000_CWu         2.655734       1.795650
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle      12.280270      15.391988
# J2_BXLS_main_exp_test_generator_996_Oracle      11.627475      12.048510
# J2_BXLS_main_exp_test_generator_997_Oracle       6.807740       8.030174
# J2_BXLS_main_exp_test_generator_998_Oracle      13.485399      11.673827
# J2_BXLS_main_exp_test_generator_999_Oracle       9.047952       5.011295
#
#                                             SINRo_MVDR_A2  DSINR_MVDR_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            4.970397       3.082795
# J2_BXLS_main_exp_test_generator_1_CWu            2.326287       4.588244
# J2_BXLS_main_exp_test_generator_10_CWu           4.118375       1.817979
# J2_BXLS_main_exp_test_generator_100_CWu          2.891196       2.286315
# J2_BXLS_main_exp_test_generator_1000_CWu         1.823194       0.963110
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle       5.175887       8.287605
# J2_BXLS_main_exp_test_generator_996_Oracle       8.159076       8.580111
# J2_BXLS_main_exp_test_generator_997_Oracle       6.001179       7.223613
# J2_BXLS_main_exp_test_generator_998_Oracle       6.289213       4.477642
# J2_BXLS_main_exp_test_generator_999_Oracle       4.417821       0.381165
#
#                                              SIRi_A2  SIRo_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu       2.234903      8.099090
# J2_BXLS_main_exp_test_generator_1_CWu      -2.143446      5.286884
# J2_BXLS_main_exp_test_generator_10_CWu      2.836967      5.392587
# J2_BXLS_main_exp_test_generator_100_CWu     0.742349      5.149652
# J2_BXLS_main_exp_test_generator_1000_CWu    1.092972      2.841606
# ...                                              ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle -2.983363     12.687243
# J2_BXLS_main_exp_test_generator_996_Oracle  0.301846     14.239558
# J2_BXLS_main_exp_test_generator_997_Oracle  4.787071     13.969402
# J2_BXLS_main_exp_test_generator_998_Oracle  1.976796     14.664311
# J2_BXLS_main_exp_test_generator_999_Oracle  6.081380     12.094866
#
#                                             DSIR_LCMV_A2  SIRo_MVDR_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           5.864187      5.277358
# J2_BXLS_main_exp_test_generator_1_CWu           7.430330      2.388644
# J2_BXLS_main_exp_test_generator_10_CWu          2.555619      4.398075
# J2_BXLS_main_exp_test_generator_100_CWu         4.407304      2.974689
# J2_BXLS_main_exp_test_generator_1000_CWu        1.748634      1.896376
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     15.670606      5.234231
# J2_BXLS_main_exp_test_generator_996_Oracle     13.937713      8.885029
# J2_BXLS_main_exp_test_generator_997_Oracle      9.182331      9.500436
# J2_BXLS_main_exp_test_generator_998_Oracle     12.687515      6.398651
# J2_BXLS_main_exp_test_generator_999_Oracle      6.013485      5.147185
#
#                                             DSIR_MVDR_A2    SNRi_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           3.042455  12.528439
# J2_BXLS_main_exp_test_generator_1_CWu           4.532090  13.969975
# J2_BXLS_main_exp_test_generator_10_CWu          1.561107  11.965292
# J2_BXLS_main_exp_test_generator_100_CWu         2.232340  16.879866
# J2_BXLS_main_exp_test_generator_1000_CWu        0.803404  13.515451
# ...                                                  ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle      8.217594  13.232780
# J2_BXLS_main_exp_test_generator_996_Oracle      8.583183   7.892737
# J2_BXLS_main_exp_test_generator_997_Oracle      4.713365   0.123503
# J2_BXLS_main_exp_test_generator_998_Oracle      4.421855  16.375599
# J2_BXLS_main_exp_test_generator_999_Oracle     -0.934196   8.493587
#
#                                             SNRo_LCMV_A2  DSNR_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          15.128659      2.600221
# J2_BXLS_main_exp_test_generator_1_CWu          18.496716      4.526740
# J2_BXLS_main_exp_test_generator_10_CWu         15.076666      3.111374
# J2_BXLS_main_exp_test_generator_100_CWu        20.323229      3.443363
# J2_BXLS_main_exp_test_generator_1000_CWu       17.810093      4.294641
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     22.108200      8.875420
# J2_BXLS_main_exp_test_generator_996_Oracle     15.128796      7.236058
# J2_BXLS_main_exp_test_generator_997_Oracle      7.693133      7.569630
# J2_BXLS_main_exp_test_generator_998_Oracle     20.022076      3.646477
# J2_BXLS_main_exp_test_generator_999_Oracle     11.806998      3.313412
#
#                                             SNRo_MVDR_A2  DSNR_MVDR_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          17.077766      4.549328
# J2_BXLS_main_exp_test_generator_1_CWu          21.014919      7.044944
# J2_BXLS_main_exp_test_generator_10_CWu         16.772049      4.806757
# J2_BXLS_main_exp_test_generator_100_CWu        22.627300      5.747435
# J2_BXLS_main_exp_test_generator_1000_CWu       21.201839      7.686388
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle     23.070383      9.837603
# J2_BXLS_main_exp_test_generator_996_Oracle     16.614044      8.721307
# J2_BXLS_main_exp_test_generator_997_Oracle      8.518857      8.395354
# J2_BXLS_main_exp_test_generator_998_Oracle     23.206663      6.831064
# J2_BXLS_main_exp_test_generator_999_Oracle     13.133126      4.639540
#
#                                             HGSDRi_A2  HGSDRo_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        1.887603        5.907581
# J2_BXLS_main_exp_test_generator_1_CWu       -2.261957        2.974086
# J2_BXLS_main_exp_test_generator_10_CWu       2.300396        3.343385
# J2_BXLS_main_exp_test_generator_100_CWu      0.604880        2.878404
# J2_BXLS_main_exp_test_generator_1000_CWu     0.860084        1.633270
# ...                                               ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle  -3.111719        5.976458
# J2_BXLS_main_exp_test_generator_996_Oracle  -0.421034        8.444800
# J2_BXLS_main_exp_test_generator_997_Oracle  -1.222434        4.738314
# J2_BXLS_main_exp_test_generator_998_Oracle   1.811572        7.864922
# J2_BXLS_main_exp_test_generator_999_Oracle   4.036656        8.113889
#
#                                             DHGSDR_LCMV_A2  HGSDRo_MVDR_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             4.019978        4.166112
# J2_BXLS_main_exp_test_generator_1_CWu             5.236043        1.287557
# J2_BXLS_main_exp_test_generator_10_CWu            1.042988        2.998742
# J2_BXLS_main_exp_test_generator_100_CWu           2.273523        1.480261
# J2_BXLS_main_exp_test_generator_1000_CWu          0.773186        0.976114
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle        9.088177        3.241847
# J2_BXLS_main_exp_test_generator_996_Oracle        8.865835        6.539528
# J2_BXLS_main_exp_test_generator_997_Oracle        5.960748        4.431493
# J2_BXLS_main_exp_test_generator_998_Oracle        6.053350        5.371050
# J2_BXLS_main_exp_test_generator_999_Oracle        4.077232        4.165944
#
#                                             DHGSDR_MVDR_A2  Gt_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             2.278510   -0.297606
# J2_BXLS_main_exp_test_generator_1_CWu             3.549514   -0.108234
# J2_BXLS_main_exp_test_generator_10_CWu            0.698345   -0.657877
# J2_BXLS_main_exp_test_generator_100_CWu           0.875381   -0.809163
# J2_BXLS_main_exp_test_generator_1000_CWu          0.116029   -0.510597
# ...                                                    ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle        6.353566   -0.447176
# J2_BXLS_main_exp_test_generator_996_Oracle        6.960563    0.204275
# J2_BXLS_main_exp_test_generator_997_Oracle        5.653927    0.104517
# J2_BXLS_main_exp_test_generator_998_Oracle        3.559479    0.420241
# J2_BXLS_main_exp_test_generator_999_Oracle        0.129288    0.043850
#
#                                             Gt_MVDR_A2  Gi_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -0.374535   -6.161792
# J2_BXLS_main_exp_test_generator_1_CWu        -0.511828   -7.538564
# J2_BXLS_main_exp_test_generator_10_CWu       -0.669968   -3.213496
# J2_BXLS_main_exp_test_generator_100_CWu      -1.056034   -5.216467
# J2_BXLS_main_exp_test_generator_1000_CWu     -1.036622   -2.259231
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle   -0.511924  -16.117783
# J2_BXLS_main_exp_test_generator_996_Oracle    0.233144  -13.733437
# J2_BXLS_main_exp_test_generator_997_Oracle    0.057059   -9.077814
# J2_BXLS_main_exp_test_generator_998_Oracle    0.114733  -12.267275
# J2_BXLS_main_exp_test_generator_999_Oracle    0.040142   -5.969636
#
#                                             Gi_MVDR_A2  Gn_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -3.416990   -2.897826
# J2_BXLS_main_exp_test_generator_1_CWu        -5.043917   -4.634975
# J2_BXLS_main_exp_test_generator_10_CWu       -2.231075   -3.769251
# J2_BXLS_main_exp_test_generator_100_CWu      -3.288374   -4.252527
# J2_BXLS_main_exp_test_generator_1000_CWu     -1.840026   -4.805240
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle   -8.729518   -9.322596
# J2_BXLS_main_exp_test_generator_996_Oracle   -8.350039   -7.031784
# J2_BXLS_main_exp_test_generator_997_Oracle   -4.656306   -7.465114
# J2_BXLS_main_exp_test_generator_998_Oracle   -4.307123   -3.226236
# J2_BXLS_main_exp_test_generator_999_Oracle    0.974337   -3.269562
#
#                                             Gn_MVDR_A2  Dt_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        -4.923863   11.887717
# J2_BXLS_main_exp_test_generator_1_CWu        -7.556772    7.702422
# J2_BXLS_main_exp_test_generator_10_CWu       -5.476725    9.680763
# J2_BXLS_main_exp_test_generator_100_CWu      -6.803469    8.089375
# J2_BXLS_main_exp_test_generator_1000_CWu     -8.723009    8.920877
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle  -10.349525    7.518021
# J2_BXLS_main_exp_test_generator_996_Oracle   -8.488163   11.092173
# J2_BXLS_main_exp_test_generator_997_Oracle   -8.338295    8.574409
# J2_BXLS_main_exp_test_generator_998_Oracle   -6.716332    8.903488
# J2_BXLS_main_exp_test_generator_999_Oracle   -4.599399   15.748595
#
#                                             Dt_MVDR_A2  Di_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        12.037300    1.947540
# J2_BXLS_main_exp_test_generator_1_CWu         8.601457    1.528441
# J2_BXLS_main_exp_test_generator_10_CWu       10.226234    2.953159
# J2_BXLS_main_exp_test_generator_100_CWu       7.672737    0.487340
# J2_BXLS_main_exp_test_generator_1000_CWu      9.182598    2.055859
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle    8.142493    0.856100
# J2_BXLS_main_exp_test_generator_996_Oracle   11.307417    0.760478
# J2_BXLS_main_exp_test_generator_997_Oracle    9.267122    0.569392
# J2_BXLS_main_exp_test_generator_998_Oracle   12.469385    0.840011
# J2_BXLS_main_exp_test_generator_999_Oracle   15.001039    1.252728
#
#                                             Di_MVDR_A2  Dn_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         2.147676    1.862721
# J2_BXLS_main_exp_test_generator_1_CWu         2.379134    0.642826
# J2_BXLS_main_exp_test_generator_10_CWu        3.850175    1.320153
# J2_BXLS_main_exp_test_generator_100_CWu       3.408709    0.960063
# J2_BXLS_main_exp_test_generator_1000_CWu      4.613189    0.679786
# ...                                                ...         ...
# J2_BXLS_main_exp_test_generator_995_Oracle    1.964852    0.380846
# J2_BXLS_main_exp_test_generator_996_Oracle    0.419850    0.774846
# J2_BXLS_main_exp_test_generator_997_Oracle   -0.036781    1.226386
# J2_BXLS_main_exp_test_generator_998_Oracle    5.361886   -1.125511
# J2_BXLS_main_exp_test_generator_999_Oracle   -1.279742    2.974442
#
#                                             Dn_MVDR_A2  SINRi_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu         2.022689 -4.493484
# J2_BXLS_main_exp_test_generator_1_CWu         1.159443 -5.892910
# J2_BXLS_main_exp_test_generator_10_CWu        1.935181 -5.551304
# J2_BXLS_main_exp_test_generator_100_CWu       1.245036 -4.086984
# J2_BXLS_main_exp_test_generator_1000_CWu      1.086589 -2.633723
# ...                                                ...       ...
# J2_BXLS_main_exp_test_generator_995_Oracle    0.539205 -1.543565
# J2_BXLS_main_exp_test_generator_996_Oracle    0.805682 -5.682048
# J2_BXLS_main_exp_test_generator_997_Oracle    0.972433 -2.566458
# J2_BXLS_main_exp_test_generator_998_Oracle    1.260814 -6.720321
# J2_BXLS_main_exp_test_generator_999_Oracle    2.555898 -0.129653
#
#                                             SINRo_LCMV_A3  DSINR_LCMV_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           -2.648794       1.844690
# J2_BXLS_main_exp_test_generator_1_CWu           -2.738860       3.154051
# J2_BXLS_main_exp_test_generator_10_CWu          -2.798651       2.752654
# J2_BXLS_main_exp_test_generator_100_CWu         -1.639471       2.447512
# J2_BXLS_main_exp_test_generator_1000_CWu         0.346780       2.980503
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle       2.442559       3.986125
# J2_BXLS_main_exp_test_generator_996_Oracle       2.911977       8.594025
# J2_BXLS_main_exp_test_generator_997_Oracle       1.140640       3.707098
# J2_BXLS_main_exp_test_generator_998_Oracle       6.270556      12.990877
# J2_BXLS_main_exp_test_generator_999_Oracle       5.628728       5.758380
#
#                                             SINRo_MVDR_A3  DSINR_MVDR_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu           -4.427970       0.065513
# J2_BXLS_main_exp_test_generator_1_CWu           -4.753055       1.139856
# J2_BXLS_main_exp_test_generator_10_CWu          -3.746444       1.804861
# J2_BXLS_main_exp_test_generator_100_CWu         -2.009335       2.077649
# J2_BXLS_main_exp_test_generator_1000_CWu        -1.403412       1.230311
# ...                                                   ...            ...
# J2_BXLS_main_exp_test_generator_995_Oracle       2.821063       4.364628
# J2_BXLS_main_exp_test_generator_996_Oracle      -1.991738       3.690310
# J2_BXLS_main_exp_test_generator_997_Oracle      -0.415738       2.150721
# J2_BXLS_main_exp_test_generator_998_Oracle       0.343614       7.063935
# ...
# J2_BXLS_main_exp_test_generator_100_CWu              NaN           NaN
# J2_BXLS_main_exp_test_generator_1000_CWu             NaN           NaN
# ...                                                  ...           ...
# J2_BXLS_main_exp_test_generator_995_Oracle           NaN           NaN
# J2_BXLS_main_exp_test_generator_996_Oracle           NaN           NaN
# J2_BXLS_main_exp_test_generator_997_Oracle           NaN           NaN
# J2_BXLS_main_exp_test_generator_998_Oracle           NaN           NaN
# J2_BXLS_main_exp_test_generator_999_Oracle           NaN           NaN
#
#                                               SISDRi  SISDRo_LCMV  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu      -0.119528     0.308459
# J2_BXLS_main_exp_test_generator_1_CWu      -1.008364    -0.587947
# J2_BXLS_main_exp_test_generator_10_CWu     -0.735848     0.196574
# J2_BXLS_main_exp_test_generator_100_CWu     0.955720     0.509693
# J2_BXLS_main_exp_test_generator_1000_CWu    0.799638     0.851643
# ...                                              ...          ...
# J2_BXLS_main_exp_test_generator_995_Oracle  0.998259     4.689526
# J2_BXLS_main_exp_test_generator_996_Oracle -2.570399     4.074922
# J2_BXLS_main_exp_test_generator_997_Oracle -2.825959     1.672000
# J2_BXLS_main_exp_test_generator_998_Oracle  2.510520     9.154840
# J2_BXLS_main_exp_test_generator_999_Oracle  0.862502     5.497151
#
#                                             DSISDR_LCMV  SISDRo_MVDR  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          0.427987     0.260916
# J2_BXLS_main_exp_test_generator_1_CWu          0.420418    -0.263443
# J2_BXLS_main_exp_test_generator_10_CWu         0.932422     0.394966
# J2_BXLS_main_exp_test_generator_100_CWu       -0.446027     1.297926
# J2_BXLS_main_exp_test_generator_1000_CWu       0.052004     1.021704
# ...                                                 ...          ...
# J2_BXLS_main_exp_test_generator_995_Oracle     3.691266     4.914717
# J2_BXLS_main_exp_test_generator_996_Oracle     6.645321     1.398996
# J2_BXLS_main_exp_test_generator_997_Oracle     4.497959     1.016502
# J2_BXLS_main_exp_test_generator_998_Oracle     6.644321     6.772819
# J2_BXLS_main_exp_test_generator_999_Oracle     4.634649     3.154042
#
#                                             DSISDR_MVDR  SISDRi_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          0.380444  10.248123
# J2_BXLS_main_exp_test_generator_1_CWu          0.744921  16.470716
# J2_BXLS_main_exp_test_generator_10_CWu         1.130814  12.184086
# J2_BXLS_main_exp_test_generator_100_CWu        0.342206  14.599818
# J2_BXLS_main_exp_test_generator_1000_CWu       0.222066  17.418182
# ...                                                 ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle     3.916457  19.237747
# J2_BXLS_main_exp_test_generator_996_Oracle     3.969396   5.760827
# J2_BXLS_main_exp_test_generator_997_Oracle     3.842462   1.742313
# J2_BXLS_main_exp_test_generator_998_Oracle     4.262300  19.224480
# J2_BXLS_main_exp_test_generator_999_Oracle     2.291540   3.144357
#
#                                             SISDRo_LCMV_A1  DSISDR_LCMV_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             6.727467       -3.520657
# J2_BXLS_main_exp_test_generator_1_CWu             7.657513       -8.813204
# J2_BXLS_main_exp_test_generator_10_CWu            8.896328       -3.287758
# J2_BXLS_main_exp_test_generator_100_CWu           8.314560       -6.285258
# J2_BXLS_main_exp_test_generator_1000_CWu         10.154757       -7.263425
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle       12.898303       -6.339444
# J2_BXLS_main_exp_test_generator_996_Oracle        8.537484        2.776658
# J2_BXLS_main_exp_test_generator_997_Oracle        5.140378        3.398066
# J2_BXLS_main_exp_test_generator_998_Oracle       14.399963       -4.824516
# J2_BXLS_main_exp_test_generator_999_Oracle        5.051934        1.907577
#
#                                             SISDRo_MVDR_A1  DSISDR_MVDR_A1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             6.727474       -3.520649
# J2_BXLS_main_exp_test_generator_1_CWu             7.657863       -8.812854
# J2_BXLS_main_exp_test_generator_10_CWu            8.896463       -3.287622
# J2_BXLS_main_exp_test_generator_100_CWu           8.314553       -6.285265
# J2_BXLS_main_exp_test_generator_1000_CWu         10.165552       -7.252630
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle       12.893467       -6.344280
# J2_BXLS_main_exp_test_generator_996_Oracle        8.536982        2.776155
# J2_BXLS_main_exp_test_generator_997_Oracle        5.063064        3.320751
# J2_BXLS_main_exp_test_generator_998_Oracle       14.427916       -4.796564
# J2_BXLS_main_exp_test_generator_999_Oracle        5.041857        1.897500
#
#                                             SISDRi_A2  SISDRo_LCMV_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu        1.894745        5.761909
# J2_BXLS_main_exp_test_generator_1_CWu       -2.118652        2.298268
# J2_BXLS_main_exp_test_generator_10_CWu       2.339643        3.061972
# J2_BXLS_main_exp_test_generator_100_CWu      0.718395        2.471677
# J2_BXLS_main_exp_test_generator_1000_CWu     0.912473        1.175667
# ...                                               ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle  -2.590988        5.547816
# J2_BXLS_main_exp_test_generator_996_Oracle  -0.366216        8.125185
# J2_BXLS_main_exp_test_generator_997_Oracle  -1.395102        4.087529
# J2_BXLS_main_exp_test_generator_998_Oracle   1.800497        7.347555
# J2_BXLS_main_exp_test_generator_999_Oracle   4.159546        7.991241
#
#                                             DSISDR_LCMV_A2  SISDRo_MVDR_A2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             3.867165        4.070786
# J2_BXLS_main_exp_test_generator_1_CWu             4.416920        0.964806
# J2_BXLS_main_exp_test_generator_10_CWu            0.722329        2.822845
# J2_BXLS_main_exp_test_generator_100_CWu           1.753282        1.183729
# J2_BXLS_main_exp_test_generator_1000_CWu          0.263194        0.721577
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle        8.138804        2.770159
# J2_BXLS_main_exp_test_generator_996_Oracle        8.491401        6.239674
# J2_BXLS_main_exp_test_generator_997_Oracle        5.482632        3.916118
# J2_BXLS_main_exp_test_generator_998_Oracle        5.547058        5.132573
# J2_BXLS_main_exp_test_generator_999_Oracle        3.831695        3.782221
#
#                                             DSISDR_MVDR_A2  SISDRi_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             2.176041  -4.340874
# J2_BXLS_main_exp_test_generator_1_CWu             3.083458  -5.929250
# J2_BXLS_main_exp_test_generator_10_CWu            0.483202  -5.746987
# J2_BXLS_main_exp_test_generator_100_CWu           0.465334  -3.501280
# J2_BXLS_main_exp_test_generator_1000_CWu         -0.190896  -2.711835
# ...                                                    ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle        5.361147  -1.641837
# J2_BXLS_main_exp_test_generator_996_Oracle        6.605890  -5.628427
# J2_BXLS_main_exp_test_generator_997_Oracle        5.311221  -2.947734
# J2_BXLS_main_exp_test_generator_998_Oracle        3.332076  -6.526501
# J2_BXLS_main_exp_test_generator_999_Oracle       -0.377325  -0.136144
#
#                                             SISDRo_LCMV_A3  DSISDR_LCMV_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            -4.889463       -0.548590
# J2_BXLS_main_exp_test_generator_1_CWu            -6.500608       -0.571359
# J2_BXLS_main_exp_test_generator_10_CWu           -5.863029       -0.116042
# J2_BXLS_main_exp_test_generator_100_CWu          -3.904739       -0.403459
# J2_BXLS_main_exp_test_generator_1000_CWu         -3.261929       -0.550094
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle        1.234704        2.876541
# J2_BXLS_main_exp_test_generator_996_Oracle        0.471323        6.099750
# J2_BXLS_main_exp_test_generator_997_Oracle       -0.262534        2.685200
# J2_BXLS_main_exp_test_generator_998_Oracle        4.372633       10.899134
# J2_BXLS_main_exp_test_generator_999_Oracle        3.034590        3.170734
#
#                                             SISDRo_MVDR_A3  DSISDR_MVDR_A3  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu            -4.983088       -0.642215
# J2_BXLS_main_exp_test_generator_1_CWu            -6.268979       -0.339729
# J2_BXLS_main_exp_test_generator_10_CWu           -5.485575        0.261412
# J2_BXLS_main_exp_test_generator_100_CWu          -2.951350        0.549930
# J2_BXLS_main_exp_test_generator_1000_CWu         -2.659849        0.051986
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle        1.851583        3.493421
# J2_BXLS_main_exp_test_generator_996_Oracle       -2.524816        3.103611
# J2_BXLS_main_exp_test_generator_997_Oracle       -1.141179        1.806555
# J2_BXLS_main_exp_test_generator_998_Oracle       -0.348787        6.177714
# J2_BXLS_main_exp_test_generator_999_Oracle        1.873477        2.009621
#
#                                             SISDRi_D1  SISDRo_LCMV_D1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu             NaN             NaN
# J2_BXLS_main_exp_test_generator_1_CWu             NaN             NaN
# J2_BXLS_main_exp_test_generator_10_CWu            NaN             NaN
# J2_BXLS_main_exp_test_generator_100_CWu           NaN             NaN
# J2_BXLS_main_exp_test_generator_1000_CWu          NaN             NaN
# ...                                               ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle        NaN             NaN
# J2_BXLS_main_exp_test_generator_996_Oracle        NaN             NaN
# J2_BXLS_main_exp_test_generator_997_Oracle        NaN             NaN
# J2_BXLS_main_exp_test_generator_998_Oracle        NaN             NaN
# J2_BXLS_main_exp_test_generator_999_Oracle        NaN             NaN
#
#                                             DSISDR_LCMV_D1  SISDRo_MVDR_D1  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_1_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_10_CWu                 NaN             NaN
# J2_BXLS_main_exp_test_generator_100_CWu                NaN             NaN
# J2_BXLS_main_exp_test_generator_1000_CWu               NaN             NaN
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_996_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_997_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_998_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_999_Oracle             NaN             NaN
#
#                                             DSISDR_MVDR_D1  SISDRi_D2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu                  NaN        NaN
# J2_BXLS_main_exp_test_generator_1_CWu                  NaN        NaN
# J2_BXLS_main_exp_test_generator_10_CWu                 NaN        NaN
# J2_BXLS_main_exp_test_generator_100_CWu                NaN        NaN
# J2_BXLS_main_exp_test_generator_1000_CWu               NaN        NaN
# ...                                                    ...        ...
# J2_BXLS_main_exp_test_generator_995_Oracle             NaN        NaN
# J2_BXLS_main_exp_test_generator_996_Oracle             NaN        NaN
# J2_BXLS_main_exp_test_generator_997_Oracle             NaN        NaN
# J2_BXLS_main_exp_test_generator_998_Oracle             NaN        NaN
# J2_BXLS_main_exp_test_generator_999_Oracle             NaN        NaN
#
#                                             SISDRo_LCMV_D2  DSISDR_LCMV_D2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_1_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_10_CWu                 NaN             NaN
# J2_BXLS_main_exp_test_generator_100_CWu                NaN             NaN
# J2_BXLS_main_exp_test_generator_1000_CWu               NaN             NaN
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_996_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_997_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_998_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_999_Oracle             NaN             NaN
#
#                                             SISDRo_MVDR_D2  DSISDR_MVDR_D2  \
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_1_CWu                  NaN             NaN
# J2_BXLS_main_exp_test_generator_10_CWu                 NaN             NaN
# J2_BXLS_main_exp_test_generator_100_CWu                NaN             NaN
# J2_BXLS_main_exp_test_generator_1000_CWu               NaN             NaN
# ...                                                    ...             ...
# J2_BXLS_main_exp_test_generator_995_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_996_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_997_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_998_Oracle             NaN             NaN
# J2_BXLS_main_exp_test_generator_999_Oracle             NaN             NaN
#
#                                             method
# scenario_id
# J2_BXLS_main_exp_test_generator_0_CWu          CWu
# J2_BXLS_main_exp_test_generator_1_CWu          CWu
# J2_BXLS_main_exp_test_generator_10_CWu         CWu
# J2_BXLS_main_exp_test_generator_100_CWu        CWu
# J2_BXLS_main_exp_test_generator_1000_CWu       CWu
# ...                                            ...
# J2_BXLS_main_exp_test_generator_995_Oracle  Oracle
# J2_BXLS_main_exp_test_generator_996_Oracle  Oracle
# J2_BXLS_main_exp_test_generator_997_Oracle  Oracle
# J2_BXLS_main_exp_test_generator_998_Oracle  Oracle
# J2_BXLS_main_exp_test_generator_999_Oracle  Oracle
#
# [21120 rows x 357 columns]

# %%
dfs["OracleSAD"]
# print a list of unique metric names. All columns are somehow metrics but many of them are just the same metric with onther beaformer or for another segment. So for each metric i only wnat to consider the first part until the first underscore and i want to have a unique list of these metric names
metric_names = set()
for col in dfs["OracleSAD"].columns:
    metric_name = col.split("_")[0]  # get the part before the first underscore
    metric_names.add(metric_name)
print("Unique metric names:", sorted(metric_names))
# Out:
# Unique metric names: ['DFWSSNR', 'DHGSDR', 'DPESQ', 'DSDR', 'DSINR', 'DSIR', 'DSISDR', 'DSNR', 'DSTOI', 'Di', 'Dn', 'Dt', 'FWSSNRi', 'FWSSNRo', 'Gi', 'Gn', 'Gt', 'HGSDRi', 'HGSDRo', 'MHA', 'PESQi', 'PESQo', 'SDRi', 'SDRo', 'SINRi', 'SINRo', 'SIRi', 'SIRo', 'SISDRi', 'SISDRo', 'SNRi', 'SNRo', 'STOIi', 'STOIo', 'WMHA', 'fixed', 'input', 'method']

# %%
# print all columns in the dataframe, really all not printing dots
pd.set_option('display.max_columns', None)
print("Columns in the combined dataframe:", df_all.columns.tolist()[10:30])
# print all columns which have a 'SMVDR' in their name
smvdr_columns = [col for col in dfs["OracleSAD"].columns if "SMVDR" in col]
print("Columns with 'SMVDR' in their name:", smvdr_columns)
# print the dataframe with only the columns which have 'SMVDR' in their name
print(dfs["OracleSAD"][smvdr_columns])
# Out:
# Columns in the combined dataframe: ['MHA_D2', 'WMHA_D2', 'SINRi', 'SINRo_LCMV', 'DSINR_LCMV', 'SINRo_MVDR', 'DSINR_MVDR', 'SIRi', 'SIRo_LCMV', 'DSIR_LCMV', 'SIRo_MVDR', 'DSIR_MVDR', 'SNRi', 'SNRo_LCMV', 'DSNR_LCMV', 'SNRo_MVDR', 'DSNR_MVDR', 'HGSDRi', 'HGSDRo_LCMV', 'DHGSDR_LCMV']
# Columns with 'SMVDR' in their name: []
# Empty DataFrame
# Columns: []
# Index: [Klaus_PALD_3D_1_test_generator_0_BOPO-W, Klaus_PALD_3D_1_test_generator_1_BOPO-W, Klaus_PALD_3D_1_test_generator_10_BOPO-W, Klaus_PALD_3D_1_test_generator_100_BOPO-W, Klaus_PALD_3D_1_test_generator_101_BOPO-W, Klaus_PALD_3D_1_test_generator_102_BOPO-W, Klaus_PALD_3D_1_test_generator_103_BOPO-W, Klaus_PALD_3D_1_test_generator_104_BOPO-W, Klaus_PALD_3D_1_test_generator_105_BOPO-W, Klaus_PALD_3D_1_test_generator_106_BOPO-W, Klaus_PALD_3D_1_test_generator_107_BOPO-W, Klaus_PALD_3D_1_test_generator_108_BOPO-W, Klaus_PALD_3D_1_test_generator_109_BOPO-W, Klaus_PALD_3D_1_test_generator_11_BOPO-W, Klaus_PALD_3D_1_test_generator_110_BOPO-W, Klaus_PALD_3D_1_test_generator_111_BOPO-W, Klaus_PALD_3D_1_test_generator_112_BOPO-W, Klaus_PALD_3D_1_test_generator_113_BOPO-W, Klaus_PALD_3D_1_test_generator_114_BOPO-W, Klaus_PALD_3D_1_test_generator_115_BOPO-W, Klaus_PALD_3D_1_test_generator_116_BOPO-W, Klaus_PALD_3D_1_test_generator_117_BOPO-W, Klaus_PALD_3D_1_test_generator_118_BOPO-W, Klaus_PALD_3D_1_test_generator_119_BOPO-W, Klaus_PALD_3D_1_test_generator_12_BOPO-W, Klaus_PALD_3D_1_test_generator_120_BOPO-W, Klaus_PALD_3D_1_test_generator_121_BOPO-W, Klaus_PALD_3D_1_test_generator_122_BOPO-W, Klaus_PALD_3D_1_test_generator_123_BOPO-W, Klaus_PALD_3D_1_test_generator_124_BOPO-W, Klaus_PALD_3D_1_test_generator_125_BOPO-W, Klaus_PALD_3D_1_test_generator_126_BOPO-W, Klaus_PALD_3D_1_test_generator_127_BOPO-W, Klaus_PALD_3D_1_test_generator_128_BOPO-W, Klaus_PALD_3D_1_test_generator_129_BOPO-W, Klaus_PALD_3D_1_test_generator_13_BOPO-W, Klaus_PALD_3D_1_test_generator_130_BOPO-W, Klaus_PALD_3D_1_test_generator_131_BOPO-W, Klaus_PALD_3D_1_test_generator_132_BOPO-W, Klaus_PALD_3D_1_test_generator_133_BOPO-W, Klaus_PALD_3D_1_test_generator_134_BOPO-W, Klaus_PALD_3D_1_test_generator_135_BOPO-W, Klaus_PALD_3D_1_test_generator_136_BOPO-W, Klaus_PALD_3D_1_test_generator_137_BOPO-W, Klaus_PALD_3D_1_test_generator_138_BOPO-W, Klaus_PALD_3D_1_test_generator_139_BOPO-W, Klaus_PALD_3D_1_test_generator_14_BOPO-W, Klaus_PALD_3D_1_test_generator_140_BOPO-W, Klaus_PALD_3D_1_test_generator_141_BOPO-W, Klaus_PALD_3D_1_test_generator_142_BOPO-W, Klaus_PALD_3D_1_test_generator_143_BOPO-W, Klaus_PALD_3D_1_test_generator_144_BOPO-W, Klaus_PALD_3D_1_test_generator_145_BOPO-W, Klaus_PALD_3D_1_test_generator_146_BOPO-W, Klaus_PALD_3D_1_test_generator_147_BOPO-W, Klaus_PALD_3D_1_test_generator_148_BOPO-W, Klaus_PALD_3D_1_test_generator_149_BOPO-W, Klaus_PALD_3D_1_test_generator_15_BOPO-W, Klaus_PALD_3D_1_test_generator_150_BOPO-W, Klaus_PALD_3D_1_test_generator_151_BOPO-W, Klaus_PALD_3D_1_test_generator_152_BOPO-W, Klaus_PALD_3D_1_test_generator_153_BOPO-W, Klaus_PALD_3D_1_test_generator_154_BOPO-W, Klaus_PALD_3D_1_test_generator_155_BOPO-W, Klaus_PALD_3D_1_test_generator_156_BOPO-W, Klaus_PALD_3D_1_test_generator_157_BOPO-W, Klaus_PALD_3D_1_test_generator_158_BOPO-W, Klaus_PALD_3D_1_test_generator_159_BOPO-W, Klaus_PALD_3D_1_test_generator_16_BOPO-W, Klaus_PALD_3D_1_test_generator_160_BOPO-W, Klaus_PALD_3D_1_test_generator_161_BOPO-W, Klaus_PALD_3D_1_test_generator_162_BOPO-W, Klaus_PALD_3D_1_test_generator_163_BOPO-W, Klaus_PALD_3D_1_test_generator_164_BOPO-W, Klaus_PALD_3D_1_test_generator_165_BOPO-W, Klaus_PALD_3D_1_test_generator_166_BOPO-W, Klaus_PALD_3D_1_test_generator_167_BOPO-W, Klaus_PALD_3D_1_test_generator_168_BOPO-W, Klaus_PALD_3D_1_test_generator_169_BOPO-W, Klaus_PALD_3D_1_test_generator_17_BOPO-W, Klaus_PALD_3D_1_test_generator_170_BOPO-W, Klaus_PALD_3D_1_test_generator_171_BOPO-W, Klaus_PALD_3D_1_test_generator_172_BOPO-W, Klaus_PALD_3D_1_test_generator_173_BOPO-W, Klaus_PALD_3D_1_test_generator_174_BOPO-W, Klaus_PALD_3D_1_test_generator_175_BOPO-W, Klaus_PALD_3D_1_test_generator_176_BOPO-W, Klaus_PALD_3D_1_test_generator_177_BOPO-W, Klaus_PALD_3D_1_test_generator_178_BOPO-W, Klaus_PALD_3D_1_test_generator_179_BOPO-W, Klaus_PALD_3D_1_test_generator_18_BOPO-W, Klaus_PALD_3D_1_test_generator_180_BOPO-W, Klaus_PALD_3D_1_test_generator_181_BOPO-W, Klaus_ ...
#
# [1800 rows x 0 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# 1. defined dimensions from your LaTeX document
latex_column_width_pt = 252.0
latex_font_size_pt = 8.0

# 2. Convert to inches for matplotlib
inches_per_pt = 1.0 / 72
fig_width_in = latex_column_width_pt * inches_per_pt
golden_ratio = (5**0.5 - 1) / 2  # approx 0.618
fig_height_in = fig_width_in * golden_ratio #(9 / 16) # 16:9 ratio

# 3. Update rcParams to match LaTeX font settings precisely
mpl.use("pgf")
mpl.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'pgf.preamble': r'\usepackage{amsmath,graphicx,siunitx,bm}',
    
    # Font sizes
    'font.size': latex_font_size_pt,
    'axes.labelsize': latex_font_size_pt,      # Axis labels same as text
    'axes.titlesize': latex_font_size_pt,      # Title same as text
    'legend.fontsize': latex_font_size_pt, # Legend smaller (8pt) to fit
    'xtick.labelsize': latex_font_size_pt, # Ticks smaller (8pt)
    'ytick.labelsize': latex_font_size_pt,
    
    # Figure size
    'figure.figsize': [fig_width_in, fig_height_in],
})

def plot_metric_by_group(
    df,
    metric,
    group_by,
    xlabel,
    title,
    ylabel,
    output_file,
):
    # Create figure with the exact calculated size
    fig, ax = plt.subplots(figsize=(fig_width_in, fig_height_in), dpi=600)
    
    sns.barplot(
        data=df,
        x=group_by,
        y=metric,
        hue="method",
        errorbar="se",
        estimator=pd.Series.median,
        capsize=0.05,
        palette="colorblind", # Correct parameter
        ax=ax,
        linewidth=0.15,
    )
    
    ax.grid(True, axis='y', linestyle='--', alpha=0.7, linewidth=0.5)
    ax.set_title(title)
    ax.set_ylabel(ylabel)
    ax.set_xlabel(xlabel)
    
    # Legend handling for small figures:
    # Placing it outside on the right makes the figure too wide for a single column.
    # Placing it on top is usually safer for column-width figures.
    ax.legend(
        title=r"\textbf{Method}", 
        loc='upper center', 
        bbox_to_anchor=(0.5, 1.35), # Move up above title
        ncol=4,                     # Spread horizontally
        frameon=False,
        columnspacing=1.0,
        handletextpad=0.2
    )
    
    # Use standard margins instead of tight_layout if you want exact dimensions,
    # but tight_layout is often safer for labels not getting cut off.
    # We use pad=0.2 to minimize wasted white space
    plt.tight_layout(pad=0.2)
    
    plt.savefig(output_file)
    plt.close() # Close to free memory
    
# Now create plots for different metrics
metrics_to_plot = [
    ("WMHA", r"WMHA [°]", r"Utterance Level"),
    ("DSINR", r"SINR Improvement [dB]", r"Utterance Level"),
    ("STOIo", r"STOI", r"Utterance Level"),
    ("WMHA_A2", r"WMHA [°]", r"Segment A2"),
    ("WMHA_A3", r"WMHA [°]", r"Segment A3"),
    ("DSINR_A2", r"SINR Improvement [dB]", r"Segment A2"),
    ("DSINR_A3", r"SINR Improvement [dB]", r"Segment A3"),
    ("STOIo_A2", r"STOI", r"Segment A2"),
    ("STOIo_A3", r"STOI", r"Segment A3"),
]

for metric, ylabel, title in metrics_to_plot:
    # Ensure resultsdir is defined previously
    output_path = resultsdirs["OracleSAD"] / "plots" / f"{metric}_by_input_snr.png"
    # Ensure directory exists
    output_path.parent.mkdir(parents=True, exist_ok=True)
    
    plot_metric_by_group(
        dfs["OracleSAD"].reset_index(drop=True),
        metric=metric,
        group_by="input_snr",
        xlabel="Input SNR [dB]",
        title=title,
        ylabel=ylabel,
        output_file=output_path,
    )

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
from pathlib import Path

# 1. defined dimensions from your LaTeX document
latex_two_column_width_pt = 516.0
latex_font_size_pt = 8.0

# 2. Convert to inches for matplotlib
inches_per_pt = 1.0 / 72
fig_width_in = latex_two_column_width_pt * inches_per_pt 
golden_ratio = (5**0.5 - 1) / 2
fig_height_in = fig_width_in * golden_ratio

# 3. Update rcParams
mpl.use("pgf")
mpl.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'pgf.preamble': r'\usepackage{amsmath,graphicx,siunitx,bm}',
    'font.size': latex_font_size_pt,
    'axes.labelsize': latex_font_size_pt,      
    'axes.titlesize': latex_font_size_pt,      
    'legend.fontsize': latex_font_size_pt, 
    'xtick.labelsize': latex_font_size_pt, 
    'ytick.labelsize': latex_font_size_pt,
    'figure.figsize': [fig_width_in, fig_height_in],
})

def plot_2x2_grid_twocol(
    df,
    metrics_list, 
    group_by,
    xlabel_text,
    output_files,
    CBW_method_for_3_sources=False
):
    if len(metrics_list) > 4:
        print(f"Warning: metrics_list has {len(metrics_list)} entries. Truncating to first 4.")
        metrics_list = metrics_list[:4]
    
    # --- 1. Prepare Consistent Colors & Order ---
    all_methods = [m for m in ["GSS", "CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W", "Oracle"]]
    all_methods = method_names_short # Added for J2
    
    palette_colors = sns.color_palette("colorblind", n_colors=len(all_methods))
    method_color_map = dict(zip(all_methods, palette_colors))
    
    # Identify if we are in the COSAD Scenario where GSS should be hidden
    # Use the first output file to check for filename pattern
    if isinstance(output_files, list) and len(output_files) > 0:
        check_path = output_files[0]
    else:
        check_path = output_files
    is_cosad_plot = "COSAD" in str(check_path)

    # Create figure
    fig, axes = plt.subplots(2, 2, figsize=(fig_width_in, fig_height_in), dpi=600)
    axes_flat = axes.flatten()
    letters = ["(a)", "(b)", "(c)", "(d)"]
    min_medians = []

    for i, (metric, ylabel, title) in enumerate(metrics_list):
        ax = axes_flat[i]
        is_bottom = i >= 2
    
        # --- 2. Conditional Filtering ---
        # Exclude GSS if COSAD
        if is_cosad_plot:
            current_df = df[df["method"] != "GSS"]
        else:
            current_df = df

        # Additional Filtering for MHA (Oracle SAD or COSAD doesn't matter, MHA excludes GSS/Oracle)
        if "MHA" in metric:
            plot_df = current_df[~current_df["method"].isin(["GSS", "Oracle"])]
        else:
            plot_df = current_df

        if not CBW_method_for_3_sources and metric.endswith("_A3"):
            plot_df = plot_df[plot_df["method"] != "CBW"]

        if not plot_df.empty:
            medians = plot_df.groupby([group_by, "method"])[metric].median()
            if not medians.empty:
                min_medians.append(medians.min())
            else:
                min_medians.append(0)
        else:
            min_medians.append(0)

        current_methods = [m for m in all_methods if m in plot_df["method"].unique()]

        sns.barplot(
            data=plot_df,
            x=group_by,
            y=metric,
            hue="method",
            hue_order=current_methods,
            palette=method_color_map,
            errorbar="se",
            estimator=pd.Series.median,
            ax=ax,
            linewidth=0.15,
        )
        
        ax.grid(True, axis='y', linestyle='--', alpha=0.7, linewidth=0.5)
        ax.set_title(title, pad=3) 
        ax.set_ylabel(ylabel)
        
        if is_bottom:
            ax.set_xlabel(xlabel_text)
        else:
            ax.set_xlabel("")
            ax.set_xticklabels([]) 
            
        ax.text(-0.06, 1.1, r"{" + letters[i] + "}", 
                transform=ax.transAxes, va='top', ha='right', fontsize=latex_font_size_pt)

        if ax.get_legend():
            ax.get_legend().remove()

        # Legend Logic (Index 0)
        if i == 0:
            legend_handles = []
            
            # Iterate through ALL methods to maintain grid positions
            for m in all_methods:
                if is_cosad_plot and m in ["GSS", "Oracle"]:
                    # Create an invisible patch for GSS (preserves the grid slot)
                    # Label is empty or spaces to keep alignment without showing text
                    legend_handles.append(mpatches.Patch(color="none", label="", alpha=0))
                else:
                    legend_handles.append(mpatches.Patch(color=method_color_map[m], label=m))
            
            ax.legend(
                handles=legend_handles,
                loc='upper right', 
                ncol=4, 
                frameon=True,
                columnspacing=0.5,
                handletextpad=0.2,
                labelspacing=0.2,
                fontsize=latex_font_size_pt
            )

    # --- Shared Y-Axis Scaling ---
    r1_min_data = min(min_medians[0], min_medians[1])
    r1_ymin = np.floor(r1_min_data - 1)
    r1_ymax = max(axes_flat[0].get_ylim()[1], axes_flat[1].get_ylim()[1])
    axes_flat[0].set_ylim(r1_ymin, r1_ymax)
    axes_flat[1].set_ylim(r1_ymin, r1_ymax)
    
    r2_min_data = min(min_medians[2], min_medians[3])
    r2_ymin = np.floor(r2_min_data - 1)
    r2_ymax = max(axes_flat[2].get_ylim()[1], axes_flat[3].get_ylim()[1])
    axes_flat[2].set_ylim(r2_ymin, r2_ymax)
    axes_flat[3].set_ylim(r2_ymin, r2_ymax)

    plt.tight_layout(pad=0.5, w_pad=1.5, h_pad=1.5)
    
    if isinstance(output_files, list):
        for of in output_files:
            plt.savefig(of, bbox_inches='tight', pad_inches=0.02)
        plt.close()
    else:
        plt.savefig(output_files, bbox_inches='tight', pad_inches=0.02)
        plt.close()


def generate_latex_table(df, sadname, output_files, CBW_method_for_3_sources=False):
    # Define method order and display names
    methods = ["GSS", "CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W", "Oracle"]
    methods = method_names_short # Added for J2
    if sadname == "OracleSAD":
        label_suffix = "OracleSAD"
    else: # COSAD
        methods = [m for m in methods if m != "GSS" and m != "Oracle"] # Exclude GSS and Oracle for COSAD
        label_suffix = "COSAD"
        
    method_labels = {
        "GSS": r"\gls{GSS}~\cite{horiguchi2021blockonlinegss}",
        "C": r"\gls{C}",
        "CSn": r"\gls{CSn}~\cite{markovich-golan_performance_2018}",
        "CWn": r"\gls{CWn}~\cite{markovich-golan_performance_2018}",
        "CSu": r"\gls{CSu}~\cite{markovich-golan_performance_2018}",
        "CWu": r"\gls{CWu}~\cite{markovich-golan_performance_2018}",
        "BOP": r"\gls{BOP}~\cite{cherkassky_successive_2020}",
        "BOP-S": r"\gls{BOP-S}~\cite{gode2025ebop}",
        "BOP-W": r"\gls{BOP-W}~\cite{gode2025ebop}",
        "BOPO": r"\gls{BOPO}~\cite{gode2025ebop}",
        "BOPO-S": r"\gls{BOPO-S}~\cite{gode2025ebop}",
        "BOPO-W": r"\gls{BOPO-W}~\cite{gode2025ebop}",
        "CB": r"\gls{CB}*",
        "CB-S": r"\gls{CB-S}*",
        "CW-B": r"\gls{CW-B}*",
        "CBW": r"\gls{CBW}~\cite{gode2023covariance}",
        "Oracle": r"Oracle"
    }
    
    # --- Configuration for Precision ---
    # Define decimal places for each metric type
    precision_config = {
        "WMHA": 1,
        "DSINR": 1
    }

    snr_levels = [0, 5, 10, 15]
    
    # Pre-calculate medians
    # Group by input_snr and method, then take median of relevant columns
    cols_of_interest = ["WMHA_A2", "DSINR_A2", "WMHA_A3", "DSINR_A3"]
    medians = df.groupby(["input_snr", "method"])[cols_of_interest].median()
    
    # Helper to find best values for bolding (min for WMHA, max for DSINR)
    # Exclude Oracle from "best" comparison for bolding
    def is_best(val, snr, metric_col, method_name, is_min=True):
        if method_name == "Oracle": 
            return False # Never bold Oracle
            
        current_methods_in_snr = medians.loc[snr].index
        # Filter methods that are in our target list AND not Oracle, GSS (for WMHA)
        comparable_methods = [m for m in methods if m in current_methods_in_snr and m != "Oracle"]
        if metric_col.startswith("WMHA"):
             comparable_methods = [m for m in comparable_methods if m != "GSS"]
             decimals = precision_config["WMHA"]
        else:
             decimals = precision_config["DSINR"]
             
        if not CBW_method_for_3_sources and metric_col.endswith("_A3"):
            comparable_methods = [m for m in comparable_methods if m != "CBW"]
             
        if not comparable_methods: 
            return False
            
        # Get all relevant values
        vals = [medians.loc[(snr, m)][metric_col] for m in comparable_methods]
        
        # Round the input value and the comparison list
        val_rounded = round(val, decimals)
        vals_rounded = [round(v, decimals) for v in vals]
        
        if is_min:
            best_val = min(vals_rounded)
            # True if the rounded value is less than or equal to the best rounded value
            return val_rounded <= best_val
        else:
            best_val = max(vals_rounded)
            # True if the rounded value is greater than or equal to the best rounded value
            return val_rounded >= best_val
    
    
    # Determine caption based on SAD name
    if sadname == "OracleSAD":
        caption = r"Median weighted Hermitian angle $\psi$ for the conventional and proposed \gls{RTF} vector estimation methods and median \gls{SINR} improvement for all considered methods for different \glspl{SNR} assuming oracle source activity knowledge."
    else:
        caption = r"Median weighted Hermitian angle $\psi$ and \gls{SINR} improvement for the conventional and proposed \gls{RTF} vector estimation methods for different \glspl{SNR} using the online source counting method~\cite{gode2026dnn}."

    # Start constructing LaTeX
    latex_str = r"""\begin{table*}[htbp!]
    \color{blue}
\centering
\begin{tabular}{p{2cm}cccccccccccc}
\toprule
\multirow{3}{2cm}{\\\textbf{Method}} & & \multicolumn{11}{c}{\textbf{\gls{SNR}}} \\
& & \multicolumn{2}{c}{0} & & \multicolumn{2}{c}{5} & & \multicolumn{2}{c}{10} & & \multicolumn{2}{c}{15} \\
\cline{3-4} \cline{6-7} \cline{9-10} \cline{12-13}
 & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ \\
\midrule
\multicolumn{13}{l}{\textbf{2 sources}} \\
\midrule
"""
    
    # --- Part 1: 2 sources (A2) ---
    prec_wmha = precision_config["WMHA"]
    prec_dsinr = precision_config["DSINR"]

    for method in methods:
        row_str = f"{method_labels[method]}         & & "
        for i, snr in enumerate(snr_levels):
            # Check if this method+snr exists in data
            if (snr, method) in medians.index:
                
                # WMHA
                if method == "GSS":
                    wmha_str = "-"
                elif method == "Oracle":
                     # Dynamic formatting for 0.0
                     wmha_str = r"$\SI{" + f"{0.0:.{prec_wmha}f}" + r"}{\degree}$"
                else:
                    val = medians.loc[(snr, method)]["WMHA_A2"]
                    formatted_val = f"{val:.{prec_wmha}f}"
                    if is_best(val, snr, "WMHA_A2", method, is_min=True):
                        wmha_str = r"\textbf{" + f"$\\SI{{{formatted_val}}}{{\\degree}}$" + "}"
                    else:
                        wmha_str = f"$\\SI{{{formatted_val}}}{{\\degree}}$"
                
                # SINR
                val_sinr = medians.loc[(snr, method)]["DSINR_A2"]
                formatted_sinr = f"{val_sinr:.{prec_dsinr}f}"
                if is_best(val_sinr, snr, "DSINR_A2", method, is_min=False):
                    sinr_str = r"\textbf{" + f"$\\SI{{{formatted_sinr}}}{{\\dB}}$" + "}"
                else:
                    sinr_str = f"$\\SI{{{formatted_sinr}}}{{\\dB}}$"
                
                row_str += f"{wmha_str} & {sinr_str}"
            else:
                row_str += " - & - "
                
            if i < len(snr_levels) - 1:
                row_str += " & & "
        
        latex_str += row_str + r" \\" + "\n"

    latex_str += r"""\midrule
\multicolumn{13}{l}{\textbf{3 sources}} \\
\midrule
"""

    # --- Part 2: 3 sources (A3) ---
    for method in methods:
        row_str = f"{method_labels[method]}         & & "
        for i, snr in enumerate(snr_levels):
            if (snr, method) in medians.index and not (not CBW_method_for_3_sources and method == "CBW"):
                 # WMHA
                if method == "GSS":
                    wmha_str = "-"
                elif method == "Oracle":
                     wmha_str = r"$\SI{" + f"{0.0:.{prec_wmha}f}" + r"}{\degree}$"
                else:
                    val = medians.loc[(snr, method)]["WMHA_A3"]
                    formatted_val = f"{val:.{prec_wmha}f}"
                    if is_best(val, snr, "WMHA_A3", method, is_min=True):
                        wmha_str = r"\textbf{" + f"$\\SI{{{formatted_val}}}{{\\degree}}$" + "}"
                    else:
                        wmha_str = f"$\\SI{{{formatted_val}}}{{\\degree}}$"
                
                # SINR
                val_sinr = medians.loc[(snr, method)]["DSINR_A3"]
                formatted_sinr = f"{val_sinr:.{prec_dsinr}f}"
                if is_best(val_sinr, snr, "DSINR_A3", method, is_min=False):
                    sinr_str = r"\textbf{" + f"$\\SI{{{formatted_sinr}}}{{\\dB}}$" + "}"
                else:
                    sinr_str = f"$\\SI{{{formatted_sinr}}}{{\\dB}}$"
                
                row_str += f"{wmha_str} & {sinr_str}"
            else:
                row_str += " - & - "
                
            if i < len(snr_levels) - 1:
                row_str += " & & "
        
        latex_str += row_str + r" \\" + "\n"
        
    # Close table
    latex_str += r"\bottomrule" + "\n"
    latex_str += r"\end{tabular}" + "\n"
    latex_str += r"\vspace{0.1cm}" + "\n"
    latex_str += f"\\caption{{{caption}}}" + "\n"
    latex_str += f"\\label{{tab:combined_{label_suffix}}}" + "\n"
    latex_str += r"\end{table*}" + "\n"
    
    if isinstance(output_files, list):
        for out_file in output_files:
            tex_path = Path(out_file).with_suffix(".tex")
            with open(tex_path, "w") as f:
                f.write(latex_str)
            print(f"Latex table saved to {tex_path}")
    else:
        tex_path = Path(output_files).with_suffix(".tex")
        with open(tex_path, "w") as f:
            f.write(latex_str)
        print(f"Latex table saved to {tex_path}")


# Define the 4 metrics to plot
metrics_to_plot_grid = [
    ("WMHA_A2", r"Weighted Hermitian Angle $\psi_{2}$ [°]", r"RTF Estimation Accuracy (2 sources)"),
    ("WMHA_A3", r"Weighted Hermitian Angle $\psi_{3}$ [°]", r"RTF Estimation Accuracy (3 sources)"),
    ("DSINR_A2", r"SINR Improvement $\Delta\text{SINR}_{2}$ [dB]", r"Source extraction performance (2 sources)"), 
    ("DSINR_A3", r"SINR Improvement $\Delta\text{SINR}_{3}$ [dB]", r"Source extraction performance (3 sources)"),
]

CBW_METHOD_FOR_3_SOURCES = False

for sadname in ["OracleSAD", "COSAD"]:
    print(f"Generating 2x2 grid plot for {sadname}...")

    # Output path
    filename = f"Main_Exp_WMHA_DSINR_S2_S3_{sadname}.pdf"
    output_path_grid = resultsdirs[sadname] / "plots" / "J2" / filename
    paper_figure_path = Path("/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/figures/Plots/revision_caused_by_J1_reviews")
    paper_out_path_grid = paper_figure_path / filename
    
    output_path_grid.parent.mkdir(parents=True, exist_ok=True)
    paper_out_path_grid.parent.mkdir(parents=True, exist_ok=True)

    output_files_list = [output_path_grid, paper_out_path_grid]

    plot_2x2_grid_twocol(
        dfs[sadname].reset_index(drop=True),
        metrics_list=metrics_to_plot_grid,
        group_by="input_snr",
        xlabel_text="Input SNR [dB]",
        output_files=output_files_list,
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
    print(f"Plot saved to {output_files_list}")
    
    # ALSO GENERATE TABLE with multiple output paths
    generate_latex_table(
        dfs[sadname].reset_index(drop=True),
        sadname,
        output_files_list,
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
# Out:
# Generating 2x2 grid plot for OracleSAD...
# Plot saved to [PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J1_BXLS_main_exp/oracle/plots/J2/Main_Exp_WMHA_DSINR_S2_S3_OracleSAD.pdf'), PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/figures/Plots/revision_caused_by_J1_reviews/Main_Exp_WMHA_DSINR_S2_S3_OracleSAD.pdf')]
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J1_BXLS_main_exp/oracle/plots/J2/Main_Exp_WMHA_DSINR_S2_S3_OracleSAD.tex
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/figures/Plots/revision_caused_by_J1_reviews/Main_Exp_WMHA_DSINR_S2_S3_OracleSAD.tex
# Generating 2x2 grid plot for COSAD...
# Plot saved to [PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J1_BXLS_main_exp/PrecomputedSAD/plots/J2/Main_Exp_WMHA_DSINR_S2_S3_COSAD.pdf'), PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/figures/Plots/revision_caused_by_J1_reviews/Main_Exp_WMHA_DSINR_S2_S3_COSAD.pdf')]
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J1_BXLS_main_exp/PrecomputedSAD/plots/J2/Main_Exp_WMHA_DSINR_S2_S3_COSAD.tex
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/figures/Plots/revision_caused_by_J1_reviews/Main_Exp_WMHA_DSINR_S2_S3_COSAD.tex

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
from pathlib import Path

# 1. defined dimensions from your LaTeX document
latex_two_column_width_pt = 516.0
latex_font_size_pt = 8.0

# 2. Convert to inches for matplotlib
inches_per_pt = 1.0 / 72
fig_width_in = latex_two_column_width_pt * inches_per_pt 
golden_ratio = (5**0.5 - 1) / 2
fig_height_in = fig_width_in * golden_ratio

# 3. Update rcParams
mpl.use("pgf")
mpl.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
    'pgf.preamble': r'\usepackage{amsmath,graphicx,siunitx,bm}',
    'font.size': latex_font_size_pt,
    'axes.labelsize': latex_font_size_pt,      
    'axes.titlesize': latex_font_size_pt,      
    'legend.fontsize': latex_font_size_pt, 
    'xtick.labelsize': latex_font_size_pt, 
    'ytick.labelsize': latex_font_size_pt,
    'figure.figsize': [fig_width_in, fig_height_in],
})

def plot_2x2_grid_twocol(
    df,
    metrics_list, 
    group_by,
    xlabel_text,
    output_files,
):
    if len(metrics_list) > 4:
        print(f"Warning: metrics_list has {len(metrics_list)} entries. Truncating to first 4.")
        metrics_list = metrics_list[:4]
    
    # --- 1. Prepare Consistent Colors & Order ---
    all_methods = [m for m in ["GSS", "CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W", "Oracle"]]
    
    palette_colors = sns.color_palette("colorblind", n_colors=len(all_methods))
    method_color_map = dict(zip(all_methods, palette_colors))
    
    # Identify if we are in the COSAD Scenario where GSS should be hidden
    # Use the first output file to check for filename pattern
    if isinstance(output_files, list) and len(output_files) > 0:
        check_path = output_files[0]
    else:
        check_path = output_files
    is_cosad_plot = "COSAD" in str(check_path)

    # Create figure
    fig, axes = plt.subplots(2, 2, figsize=(fig_width_in, fig_height_in), dpi=600)
    axes_flat = axes.flatten()
    letters = ["(a)", "(b)", "(c)", "(d)"]
    min_medians = []

    for i, (metric, ylabel, title) in enumerate(metrics_list):
        ax = axes_flat[i]
        is_bottom = i >= 2
    
        # --- 2. Conditional Filtering ---
        # Exclude GSS if COSAD
        if is_cosad_plot:
            current_df = df[df["method"] != "GSS"]
        else:
            current_df = df

        # Additional Filtering for MHA (Oracle SAD or COSAD doesn't matter, MHA excludes GSS/Oracle)
        if "MHA" in metric:
            plot_df = current_df[~current_df["method"].isin(["GSS", "Oracle"])]
        else:
            plot_df = current_df

        if not plot_df.empty:
            medians = plot_df.groupby([group_by, "method"])[metric].median()
            if not medians.empty:
                min_medians.append(medians.min())
            else:
                min_medians.append(0)
        else:
            min_medians.append(0)

        current_methods = [m for m in all_methods if m in plot_df["method"].unique()]

        sns.barplot(
            data=plot_df,
            x=group_by,
            y=metric,
            hue="method",
            hue_order=current_methods,
            palette=method_color_map,
            errorbar="se",
            estimator=pd.Series.median,
            ax=ax,
            linewidth=0.15,
        )
        
        ax.grid(True, axis='y', linestyle='--', alpha=0.7, linewidth=0.5)
        ax.set_title(title, pad=3) 
        ax.set_ylabel(ylabel)
        
        if is_bottom:
            ax.set_xlabel(xlabel_text)
        else:
            ax.set_xlabel("")
            ax.set_xticklabels([]) 
            
        ax.text(-0.06, 1.1, r"{" + letters[i] + "}", 
                transform=ax.transAxes, va='top', ha='right', fontsize=latex_font_size_pt)

        if ax.get_legend():
            ax.get_legend().remove()

        # Legend Logic (Index 0)
        if i == 0:
            legend_handles = []
            
            # Iterate through ALL methods to maintain grid positions
            for m in all_methods:
                if is_cosad_plot and m in ["GSS", "Oracle"]:
                    # Create an invisible patch for GSS (preserves the grid slot)
                    # Label is empty or spaces to keep alignment without showing text
                    legend_handles.append(mpatches.Patch(color="none", label="", alpha=0))
                else:
                    legend_handles.append(mpatches.Patch(color=method_color_map[m], label=m))
            
            ax.legend(
                handles=legend_handles,
                loc='upper right', 
                ncol=4, 
                frameon=True,
                columnspacing=0.5,
                handletextpad=0.2,
                labelspacing=0.2,
                fontsize=latex_font_size_pt
            )

    # --- Shared Y-Axis Scaling ---
    r1_min_data = min(min_medians[0], min_medians[1])
    r1_ymin = np.floor(r1_min_data - 1)
    r1_ymax = max(axes_flat[0].get_ylim()[1], axes_flat[1].get_ylim()[1])
    axes_flat[0].set_ylim(r1_ymin, r1_ymax)
    axes_flat[1].set_ylim(r1_ymin, r1_ymax)
    
    r2_min_data = min(min_medians[2], min_medians[3])
    r2_ymin = np.floor(r2_min_data - 1)
    r2_ymax = max(axes_flat[2].get_ylim()[1], axes_flat[3].get_ylim()[1])
    
    if True:
        r2_ymin = 0.4
        r2_ymax = 0.9
    
    axes_flat[2].set_ylim(r2_ymin, r2_ymax)
    axes_flat[3].set_ylim(r2_ymin, r2_ymax)

    plt.tight_layout(pad=0.5, w_pad=1.5, h_pad=1.5)
    
    if isinstance(output_files, list):
        for of in output_files:
            plt.savefig(of, bbox_inches='tight', pad_inches=0.02)
        plt.close()
    else:
        plt.savefig(output_files, bbox_inches='tight', pad_inches=0.02)
        plt.close()


def generate_latex_table(df, sadname, metrics, output_files):
    # Define method order and display names
    if sadname == "OracleSAD":
        methods = ["GSS", "CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W", "Oracle"]
        label_suffix = "OracleSAD"
    else: # COSAD
        methods = ["CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W"]
        label_suffix = "COSAD"
        
    method_labels = {
        "GSS": r"\gls{GSS}~\cite{horiguchi2021blockonlinegss}",
        "CWu": r"\gls{CWu}~\cite{markovich-golan_performance_2018}",
        "BOP": r"\gls{BOP}~\cite{cherkassky_successive_2020}",
        "BOP-S": r"\gls{BOP-S}*",
        "BOP-W": r"\gls{BOP-W}*",
        "BOPO": r"\gls{BOPO}*",
        "BOPO-S": r"\gls{BOPO-S}*",
        "BOPO-W": r"\gls{BOPO-W}*",
        "Oracle": r"Oracle"
    }

    snr_levels = [0, 5, 10, 15]
    
    # Pre-calculate medians
    # Group by input_snr and method, then take median of relevant columns
    # cols_of_interest = ["WMHA_A2", "DSINR_A2", "WMHA_A3", "DSINR_A3"]
    cols_of_interest = metrics
    medians = df.groupby(["input_snr", "method"])[cols_of_interest].median()
    
    # Helper to find best values for bolding (min for WMHA, max for DSINR)
    # Exclude Oracle from "best" comparison for bolding
    def is_best(val, snr, metric_col, method_name, is_min=True):
        if method_name == "Oracle": 
            return False # Never bold Oracle
            
        current_methods_in_snr = medians.loc[snr].index
        # Filter methods that are in our target list AND not Oracle, GSS (for WMHA)
        comparable_methods = [m for m in methods if m in current_methods_in_snr and m != "Oracle"]
        if metric_col.startswith("WMHA"):
             comparable_methods = [m for m in comparable_methods if m != "GSS"]
             
        if not comparable_methods: 
            return False
            
        vals = [medians.loc[(snr, m)][metric_col] for m in comparable_methods]
        
        if is_min:
            best_val = min(vals)
            return val <= best_val + 1e-6 # float tolerance
        else:
            best_val = max(vals)
            return val >= best_val - 1e-6
    
    
    # Determine caption based on SAD name
    if sadname == "OracleSAD":
        caption = r"Median weighted Hermitian angle $\psi$ for the conventional and proposed \gls{RTF} vector estimation methods and median \gls{SINR} improvement for all considered methods for different \glspl{SNR} assuming oracle source activity knowledge."
    else:
        caption = r"Median weighted Hermitian angle $\psi$ for the conventional and proposed \gls{RTF} vector estimation methods and median \gls{SINR} improvement for all considered methods for different \glspl{SNR} using the online source counting method~\cite{gode2026dnn}."

    # Start constructing LaTeX
    latex_str = r"""\begin{table*}[htbp]
    \color{blue}
\centering
\begin{tabular}{p{2cm}cccccccccccc}
\toprule
\multirow{3}{2cm}{\\\textbf{Method}} & & \multicolumn{11}{c}{\textbf{\gls{SNR}}} \\
& & \multicolumn{2}{c}{0} & & \multicolumn{2}{c}{5} & & \multicolumn{2}{c}{10} & & \multicolumn{2}{c}{15} \\
\cline{3-4} \cline{6-7} \cline{9-10} \cline{12-13}
 & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ & & $\psi\downarrow$ & $\Delta$\gls{SINR}$\uparrow$ \\
\midrule
\multicolumn{13}{l}{\textbf{2 sources}} \\
\midrule
"""
    
    # --- Part 1: 2 sources (A2) ---
    for method in methods:
        row_str = f"{method_labels[method]}         & & "
        for i, snr in enumerate(snr_levels):
            # Check if this method+snr exists in data
            if (snr, method) in medians.index:
                
                # WMHA
                if method == "GSS":
                    wmha_str = "-"
                elif method == "Oracle":
                     wmha_str = r"$\SI{0.0}{\degree}$"
                else:
                    val = medians.loc[(snr, method)]["WMHA_A2"]
                    if is_best(val, snr, "WMHA_A2", method, is_min=True):
                        wmha_str = r"\textbf{" + f"$\\SI{{{val:.1f}}}{{\\degree}}$" + "}"
                    else:
                        wmha_str = f"$\\SI{{{val:.1f}}}{{\\degree}}$"
                
                # SINR
                val_sinr = medians.loc[(snr, method)]["DSINR_A2"]
                if is_best(val_sinr, snr, "DSINR_A2", method, is_min=False):
                    sinr_str = r"\textbf{" + f"$\\SI{{{val_sinr:.1f}}}{{\\dB}}$" + "}"
                else:
                    sinr_str = f"$\\SI{{{val_sinr:.1f}}}{{\\dB}}$"
                
                row_str += f"{wmha_str} & {sinr_str}"
            else:
                row_str += " - & - "
                
            if i < len(snr_levels) - 1:
                row_str += " & & "
        
        latex_str += row_str + r" \\" + "\n"

    latex_str += r"""\midrule
\multicolumn{13}{l}{\textbf{3 sources}} \\
\midrule
"""

    # --- Part 2: 3 sources (A3) ---
    for method in methods:
        row_str = f"{method_labels[method]}         & & "
        for i, snr in enumerate(snr_levels):
            if (snr, method) in medians.index:
                 # WMHA
                if method == "GSS":
                    wmha_str = "-"
                elif method == "Oracle":
                     wmha_str = r"$\SI{0.0}{\degree}$"
                else:
                    val = medians.loc[(snr, method)]["WMHA_A3"]
                    if is_best(val, snr, "WMHA_A3", method, is_min=True):
                        wmha_str = r"\textbf{" + f"$\\SI{{{val:.1f}}}{{\\degree}}$" + "}"
                    else:
                        wmha_str = f"$\\SI{{{val:.1f}}}{{\\degree}}$"
                
                # SINR
                val_sinr = medians.loc[(snr, method)]["DSINR_A3"]
                if is_best(val_sinr, snr, "DSINR_A3", method, is_min=False):
                    sinr_str = r"\textbf{" + f"$\\SI{{{val_sinr:.1f}}}{{\\dB}}$" + "}"
                else:
                    sinr_str = f"$\\SI{{{val_sinr:.1f}}}{{\\dB}}$"
                
                row_str += f"{wmha_str} & {sinr_str}"
            else:
                row_str += " - & - "
                
            if i < len(snr_levels) - 1:
                row_str += " & & "
        
        latex_str += row_str + r" \\" + "\n"
        
    # Close table
    latex_str += r"\bottomrule" + "\n"
    latex_str += r"\end{tabular}" + "\n"
    latex_str += r"\vspace{0.1cm}" + "\n"
    latex_str += f"\\caption{{{caption}}}" + "\n"
    latex_str += f"\\label{{tab:combined_{label_suffix}}}" + "\n"
    latex_str += r"\end{table*}" + "\n"
    
    if isinstance(output_files, list):
        for out_file in output_files:
            tex_path = Path(out_file).with_suffix(".tex")
            with open(tex_path, "w") as f:
                f.write(latex_str)
            print(f"Latex table saved to {tex_path}")
    else:
        tex_path = Path(output_files).with_suffix(".tex")
        with open(tex_path, "w") as f:
            f.write(latex_str)
        print(f"Latex table saved to {tex_path}")


# Define the 4 metrics to plot
metrics_to_plot_grid = [
    ("WMHA_A2", r"Weighted Hermitian Angle $\psi_{2}$ [°]", r"RTF Estimation Accuracy (2 sources)"),
    ("WMHA_A3", r"Weighted Hermitian Angle $\psi_{3}$ [°]", r"RTF Estimation Accuracy (3 sources)"),
    ("DSINR_A2", r"SINR Improvement [dB]", r"Source extraction performance (2 sources)"), 
    ("DSINR_A3", r"SINR Improvement [dB]", r"Source extraction performance (3 sources)"),
    # ("STOIo_A2", r"STOI", r"Source extraction performance (2 sources)"), 
    # ("STOIo_A3", r"STOI", r"Source extraction performance (3 sources)"),
]
    
for sadname in ["OracleSAD", "COSAD"]:
    print(f"Generating 2x2 grid plot for {sadname}...")

    # Output path
    output_path_grid = resultsdirs[sadname] / "plots" / f"Main_Exp_WMHA_DSINR_S2_S3_{sadname}.pdf"
    paper_figure_path = Path("/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal1/figures/Rebuttal")
    paper_out_path_grid = paper_figure_path / f"Main_Exp_WMHA_DSINR_S2_S3_{sadname}.pdf"
    
    output_path_grid.parent.mkdir(parents=True, exist_ok=True)
    paper_out_path_grid.parent.mkdir(parents=True, exist_ok=True)

    output_files_list = [output_path_grid, paper_out_path_grid]

    plot_2x2_grid_twocol(
        dfs[sadname].reset_index(drop=True),
        metrics_list=metrics_to_plot_grid,
        group_by="input_snr",
        xlabel_text="Input SNR [dB]",
        output_files=output_files_list,
    )
    print(f"Plot saved to {output_files_list}")
    
    
    # ALSO GENERATE TABLE with multiple output paths
    generate_latex_table(
        dfs[sadname].reset_index(drop=True),
        sadname,
        [met for met, _, _ in metrics_to_plot_grid],
        output_files_list
    )
# Out:
# Generating 2x2 grid plot for OracleSAD...
# Plot saved to [PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/results/J1_BXLS_main_exp_OracleSAD/plots/Main_Exp_WMHA_STOIo_S2_S3_OracleSAD.pdf'), PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal1/figures/Rebuttal/Main_Exp_WMHA_STOIo_S2_S3_OracleSAD.pdf')]
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J1_BXLS_main_exp_OracleSAD/plots/Main_Exp_WMHA_STOIo_S2_S3_OracleSAD.tex
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/documents/Journal1/figures/Rebuttal/Main_Exp_WMHA_STOIo_S2_S3_OracleSAD.tex
# Generating 2x2 grid plot for COSAD...
# Plot saved to [PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/results/J1_BXLS_main_exp_COSAD/plots/Main_Exp_WMHA_STOIo_S2_S3_COSAD.pdf'), PosixPath('/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal1/figures/Rebuttal/Main_Exp_WMHA_STOIo_S2_S3_COSAD.pdf')]
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J1_BXLS_main_exp_COSAD/plots/Main_Exp_WMHA_STOIo_S2_S3_COSAD.tex
# Latex table saved to /data4/Henri/j3/framewiseSpeakerCounting/documents/Journal1/figures/Rebuttal/Main_Exp_WMHA_STOIo_S2_S3_COSAD.tex

# %%
# I want to have a torch tensor of size [2, 2, 4, 4, 9] whereby the dimensions correspond to the following:
# [metrics, sad_method, segment, input_snr, methods]
# metrics are either WMHA or DSINR
# sad_method is either OracleSAD or COSAD
# segment is either "" (empty referring to utterance level, A1, A2 or A3
# input_snr is either 0, 5, 10 or 15
# methods are the method_names_short defined above
import torch
import numpy as np

# 1. Define dimensions
metrics = ["WMHA", "DSINR"]
sad_methods = ["OracleSAD", "COSAD"]
# Map segment conceptual names to possible column suffixes
segment_suffixes = ["", "_A1", "_A2", "_A3"] 
input_snrs = [0, 5, 10, 15]

# Use the 9 methods corresponding to the "9" in your requested dimension
# (Excluding GSSL which was in the original loading list but not in the tables)
methods_tensor_order = ["GSS", "CWu", "BOP", "BOP-S", "BOP-W", "BOPO", "BOPO-S", "BOPO-W", "Oracle"]

# 2. Initialize Tensor
results_tensor = torch.zeros(
    len(metrics), 
    len(sad_methods), 
    len(segment_suffixes), 
    len(input_snrs), 
    len(methods_tensor_order)
)

# 3. Fill Tensor
for i_met, metric in enumerate(metrics):
    for i_sad, sad in enumerate(sad_methods):
        if sad not in dfs:
            print(f"Skipping {sad}, not in dfs")
            continue
            
        df = dfs[sad]
        
        for i_seg, seg_suffix in enumerate(segment_suffixes):
            col_name = f"{metric}{seg_suffix}"
            
            # Helper to check if column exists (e.g. A1 might be missing)
            if col_name not in df.columns:
                # print(f"  Note: Column {col_name} not found in {sad} dataframe. Filling with NaN.")
                results_tensor[i_met, i_sad, i_seg, :, :] = float('nan')
                continue
            
            for i_snr, snr in enumerate(input_snrs):
                for i_meth, method in enumerate(methods_tensor_order):
                    # Filter mask
                    mask = (df["input_snr"] == snr) & (df["method"] == method)
                    values = df.loc[mask, col_name]
                    
                    if not values.empty:
                        results_tensor[i_met, i_sad, i_seg, i_snr, i_meth] = values.median()
                    else:
                        results_tensor[i_met, i_sad, i_seg, i_snr, i_meth] = float('nan')

print(f"Created tensor with shape: {results_tensor.shape}")
print("Dimensions: [metrics, sad_method, segment, input_snr, methods]")
# Out:
# Created tensor with shape: torch.Size([2, 2, 4, 4, 9])
# Dimensions: [metrics, sad_method, segment, input_snr, methods]

# %%
compare_tensor = torch.round(results_tensor[1, 1] - results_tensor[1, 0], decimals=2)
# print the values of the compare tensor in a nicely readable format (maybe as a table)

# Dimensions of compare_tensor are [segment, input_snr, methods]
# segment indices: 0="", 1="_A1", 2="_A2", 3="_A3"
segment_names = ["Utterance", "Segment A1", "Segment A2", "Segment A3"]

# Use pandas for nice formatting
import pandas as pd
from IPython.display import display

for i_seg, seg_name in enumerate(segment_names):
    print(f"\n=======================================================")
    print(f"DSINR Difference (COSAD - OracleSAD) for {seg_name}")
    print(f"=======================================================")
    
    # Extract the 2D slice for this segment: [input_snr, methods]
    data_slice = compare_tensor[i_seg].numpy()
    
    # Create DataFrame for display
    # shape is (4, 9) -> rows=SNRs, cols=Methods
    df_compare = pd.DataFrame(
        data_slice, 
        index=[f"SNR {s}" for s in input_snrs], 
        columns=methods_tensor_order
    )
    
    display(df_compare)
# Out:
# =======================================================
# DSINR Difference (COSAD - OracleSAD) for Utterance
# =======================================================
#         GSS   CWv   BOP  BOP-S  BOP-W  BOPO  BOPO-S  BOPO-W  Oracle
# SNR 0   0.0 -0.47 -0.46  -0.51  -0.61 -0.51   -0.58   -0.74     NaN
# SNR 5   0.0 -0.40 -0.53  -0.53  -0.61 -0.62   -0.61   -0.70     NaN
# SNR 10  0.0 -0.49 -0.49  -0.41  -0.32 -0.49   -0.62   -0.48     NaN
# SNR 15  0.0 -0.45 -0.44  -0.44  -0.34 -0.61   -0.59   -0.52     NaN
# =======================================================
# DSINR Difference (COSAD - OracleSAD) for Segment A1
# =======================================================
#         GSS   CWv   BOP  BOP-S  BOP-W  BOPO  BOPO-S  BOPO-W  Oracle
# SNR 0   0.0  0.13  0.13   0.12   0.12  0.19    0.20    0.14     NaN
# SNR 5   0.0  0.14  0.15   0.17   0.12  0.14    0.22    0.12     NaN
# SNR 10  0.0  0.07  0.16   0.06   0.02  0.13    0.08    0.08     NaN
# SNR 15  0.0  0.09  0.05   0.07  -0.02  0.03    0.06    0.08     NaN
# =======================================================
# DSINR Difference (COSAD - OracleSAD) for Segment A2
# =======================================================
#         GSS   CWv   BOP  BOP-S  BOP-W  BOPO  BOPO-S  BOPO-W  Oracle
# SNR 0   0.0 -0.66 -0.31  -0.49  -0.64 -0.47   -0.52   -0.78     NaN
# SNR 5   0.0 -0.52 -0.40  -0.52  -0.58 -0.57   -0.60   -0.76     NaN
# SNR 10  0.0 -0.50 -0.33  -0.52  -0.39 -0.58   -0.60   -0.60     NaN
# SNR 15  0.0 -0.46 -0.29  -0.27  -0.39 -0.42   -0.46   -0.45     NaN
# =======================================================
# DSINR Difference (COSAD - OracleSAD) for Segment A3
# =======================================================
#         GSS   CWv   BOP  BOP-S  BOP-W  BOPO  BOPO-S  BOPO-W  Oracle
# SNR 0   0.0 -0.46 -0.64  -0.64  -0.58 -0.71   -0.66   -0.76     NaN
# SNR 5   0.0 -0.40 -0.52  -0.58  -0.61 -0.64   -0.59   -0.54     NaN
# SNR 10  0.0 -0.35 -0.48  -0.53  -0.48 -0.53   -0.55   -0.58     NaN
# SNR 15  0.0 -0.37 -0.44  -0.46  -0.46 -0.48   -0.53   -0.56     NaN

# %%
compare_tensor = torch.round(results_tensor[1, 1] - results_tensor[1, 0], decimals=2)
# print the values of the compare tensor in a nicely readable format (maybe as a table)

# %%
# # Use seaborn to create a barplot showing the median of the selected metric
# # with its std error of the median as error bars for each method,
# # grouped by a another metric (usually a meta info like input SNR or segment length)
# import seaborn as sns
# import matplotlib.pyplot as plt
# def plot_metric_by_group(
#     df,
#     metric,
#     group_by,
#     xlabel,
#     title,
#     ylabel,
#     output_file,
# ):
#     # 1. Determine order and calculate counts
#     # Get unique values and sort them to ensure consistent ordering
#     groups = sorted(df[group_by].unique())
#     # Calculate number of rows for each group value
#     counts = df[group_by].value_counts()
    
#     plt.figure(figsize=(10, 6))
    
#     # 2. Pass 'order' to ensure the plot follows our sorted groups
#     ax = sns.barplot(
#         data=df,
#         x=group_by,
#         y=metric,
#         hue="method",
#         errorbar="se",
#         estimator=pd.Series.median,
#         capsize=0.1,
#         order=groups, 
#     )
    
#     # 3. Create new labels with counts
#     # Example label: "0.5\n(N=1200)"
#     new_labels = [f"{g}\n({counts[g]})" for g in groups]
#     ax.set_xticklabels(new_labels)

#     ax.grid(True, axis='y', linestyle='--', alpha=0.7)
#     ax.set_title(title)
#     ax.set_ylabel(ylabel)
#     ax.set_xlabel(xlabel)
#     plt.legend(title="Method", bbox_to_anchor=(1.05, 1), loc='upper left')
#     plt.tight_layout()
#     plt.savefig(output_file)
#     plt.close()
    
# # Now create plots for different metrics
# metrics_to_plot = [
#     ("WMHA_A2", "WMHA [°]", "Segment A2"),
#     ("WMHA_A3", "WMHA [°]", "Segment A3"),
#     ("DSINR_A2", "SINR [dB]", "Segment A2"),
#     ("DSINR_A3", "SINR [dB]", "Segment A3"),
#     ("STOIo_A2", "STOI", "Segment A2"),
#     ("STOIo_A3", "STOI", "Segment A3"),
# ]
# for metric, ylabel, title in metrics_to_plot:
#     plot_metric_by_group(
#         df_all,
#         metric=metric,
#         group_by="input_snr",
#         xlabel="Input SNR [dB]",
#         title=f"{title}",
#         ylabel=ylabel,
#         output_file=resultsdir / "plots" /f"{metric}_by_input_snr.png",
#     )
# Out:
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# /tmp/ipykernel_2164341/2380907857.py:38: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
from pathlib import Path
import string

# ==============================================================================
# 1. CORE FUNCTIONS (Generic Logic)
# ==============================================================================

def setup_matplotlib_rc(n_metrics, n_segments, figure_width_pt=372.0, latex_font_size_pt=6.0):
    inches_per_pt = 1.0 / 72
    fig_width_in = figure_width_pt * inches_per_pt
    golden_ratio = (5**0.5 - 1) / 2
    
    # Each individual subplot should have a golden ratio.
    # Therefore the overall height ratio is height_ratio * (rows / cols)
    fig_height_in = fig_width_in * golden_ratio * (n_metrics / n_segments)

    mpl.use("pgf")
    mpl.rcParams.update({
        "pgf.texsystem": "pdflatex",
        'font.family': 'serif',
        'text.usetex': True,
        'pgf.rcfonts': False,
        'pgf.preamble': r'\usepackage{amsmath,graphicx,siunitx,bm}',
        'font.size': latex_font_size_pt,
        'axes.labelsize': latex_font_size_pt,      
        'axes.titlesize': latex_font_size_pt,      
        'legend.fontsize': latex_font_size_pt, 
        'xtick.labelsize': latex_font_size_pt, 
        'ytick.labelsize': latex_font_size_pt,
        'figure.figsize': [fig_width_in, fig_height_in],
    })
    return fig_width_in, fig_height_in

def plot_generic_grid(
    df, 
    metrics_config, 
    segments_config, 
    group_by, 
    xlabel_text, 
    output_files, 
    all_methods, 
    is_cosad, 
    fig_dims, 
    force_y_limits=None,
    CBW_method_for_3_sources=False
    ):
    fig_width_in, fig_height_in = fig_dims
    n_rows = len(metrics_config)
    n_cols = len(segments_config)
    
    # Setup Colors
    palette_colors = sns.color_palette("colorblind", n_colors=len(all_methods))
    method_color_map = dict(zip(all_methods, palette_colors))
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(fig_width_in, fig_height_in), dpi=600, squeeze=False)
    letters = list(string.ascii_lowercase)
    
    # Store min/max limits for each row to synchronize y-axes
    row_limits = {r: [float('inf'), float('-inf')] for r in range(n_rows)}

    plot_idx = 0
    for r, metric_info in enumerate(metrics_config):
        for c, segment_info in enumerate(segments_config):
            ax = axes[r, c]
            segment_str = "_" + segment_info['id'] if segment_info['id'] != "" else ""
            bfstr = metric_info.get('BF', None)
            if bfstr is not None:
                metric_col = f"{metric_info['name']}_{bfstr}{segment_str}"
            else:
                metric_col = f"{metric_info['name']}{segment_str}"
            is_bottom = (r == n_rows - 1)
            
            # --- Filtering ---
            plot_df = df.copy()
            if is_cosad: plot_df = plot_df[plot_df["method"] != "GSS"]
            if metric_info.get('exclude_oracle_gss', False): 
                plot_df = plot_df[~plot_df["method"].isin(["GSS", "Oracle"])]
                
            if not CBW_method_for_3_sources and segment_info['id'] == "A3":
                plot_df = plot_df[plot_df["method"] != "CBW"]
                
            if plot_df.empty or metric_col not in plot_df.columns:
                ax.set_visible(False)
                continue

            current_methods = [m for m in all_methods if m in plot_df["method"].unique()]

            # --- Plotting ---
            sns.barplot(
                data=plot_df, x=group_by, y=metric_col,
                hue="method", hue_order=current_methods, palette=method_color_map,
                errorbar="se", estimator=pd.Series.median, ax=ax, linewidth=0.15,
            )
            
            # Record limits for this row
            medians = plot_df[plot_df['method'].isin(current_methods)].groupby([group_by, "method"])[metric_col].median()
            if not medians.empty:
                row_limits[r][0] = min(row_limits[r][0], medians.min())
            # row_limits[r][0] = min(row_limits[r][0], ax.get_ylim()[0])    
            row_limits[r][1] = max(row_limits[r][1], ax.get_ylim()[1])
            
            # --- Styling ---
            ax.grid(True, axis='y', linestyle='--', alpha=0.7, linewidth=0.5)
            ax.set_title(f"{metric_info['title']} ({segment_info['title']})", pad=3) 
            ax.set_ylabel(metric_info['ylabel'])
            
            if is_bottom: ax.set_xlabel(xlabel_text)
            else: ax.set_xlabel(""); ax.set_xticklabels([]) 
                
            ax.text(-0.06, 1.1, r"{(" + letters[plot_idx] + ")}", transform=ax.transAxes, va='top', ha='right')
            plot_idx += 1

            if ax.get_legend(): ax.get_legend().remove()

            # --- Master Legend (Top Left Plot) ---
            if r == 0 and c == 0:
                handles = []
                for m in all_methods:
                    if is_cosad and m in ["GSS", "Oracle"]:
                        handles.append(mpatches.Patch(color="none", label="", alpha=0))
                    else:
                        handles.append(mpatches.Patch(color=method_color_map[m], label=m))
                ax.legend(handles=handles, loc='upper right', ncol=4, frameon=True, 
                          columnspacing=0.5, handletextpad=0.2, labelspacing=0.2)

    # --- Synchronize Y-Axes per row ---
    for r, metric_info in enumerate(metrics_config):
        # Allow precision to be either a float (e.g., 0.1, 0.01) or an int representing decimal places
        precision_val = metric_info.get('precision', 1)
        
        if isinstance(precision_val, float):
            precision_step = precision_val
            # Calculate format string precision based on step
            fmt_dec = len(str(precision_step).split('.')[-1]) if '.' in str(precision_step) else 0
        else:
            # Backwards compatibility: if precision is int (e.g. 1 means 0.1 step)
            precision_step = 10**(-precision_val)
            fmt_dec = precision_val
            
        # Floor based on precision step instead of just integer floor
        if row_limits[r][0] != float('inf'):
            # Multiply by 1/step, floor, then convert back
            factor = 1.0 / precision_step
            y_min = np.floor(row_limits[r][0] * factor) / factor #- precision_step
        else:
            y_min = 0
            
        y_max = row_limits[r][1]
        
        # Apply manual override if provided in config
        if force_y_limits and metric_info['name'] in force_y_limits:
            y_min, y_max = force_y_limits[metric_info['name']]

        for c in range(n_cols):
            axes[r, c].set_ylim(y_min, y_max)
            
            # Optionally format y-ticks according to precision
            axes[r, c].yaxis.set_major_formatter(mpl.ticker.FormatStrFormatter(f'%.{fmt_dec}f'))

    plt.tight_layout(pad=0.5, w_pad=1.5, h_pad=1.5)
    
    # Save
    if not isinstance(output_files, list): output_files = [output_files]
    for of in output_files:
        plt.savefig(of, bbox_inches='tight', pad_inches=0.02)
    plt.close()


def generate_generic_latex_table(df, sadname, metrics_config, segments_config, all_methods, method_labels, snr_levels, output_files, caption, CBW_method_for_3_sources=False):
    is_cosad = (sadname == "COSAD")
    methods = [m for m in all_methods if not (is_cosad and m in ["GSS", "Oracle"])]
    
    # Latex Header Construction
    num_cols = len(snr_levels) * len(metrics_config) + len(snr_levels) + 1
    header_align = "p{2cm}" + "c" * (num_cols - 1)
    
    latex_str = f"\\begin{{table*}}[htbp!]\n\\color{{black}}\n\\centering\n\\begin{{tabular}}{{{header_align}}}\n\\toprule\n"
    latex_str += "\\multirow{3}{2cm}{\\\\\\textbf{Method}} & & \\multicolumn{" + str(num_cols - 2) + "}{c}{\\textbf{\\gls{SNR}}} \\\\\n"
    
    # SNR Headers
    snr_row = "&"
    for snr in snr_levels:
        snr_row += f" & \\multicolumn{{{len(metrics_config)}}}{{c}}{{{snr}}} &"
    latex_str += snr_row[:-1] + "\\\\\n"
    
    # Line rules
    line_start = 3
    for i in range(len(snr_levels)):
        latex_str += f"\\cline{{{line_start}-{line_start+len(metrics_config)-1}}} "
        line_start += len(metrics_config) + 1
    latex_str += "\n"
    
    # Metric Headers
    metric_block = " & ".join([m['latex_header'] for m in metrics_config])
    latex_str += "& & " + " & & ".join([metric_block] * len(snr_levels)) + " \\\\\n\\midrule\n"
    
    # --- Generate Rows per Segment ---
    for seg in segments_config:
        latex_str += f"\\multicolumn{{{num_cols}}}{{l}}{{\\textbf{{{seg['title']}}}}} \\\\\n\\midrule\n"
        
        # Pre-calc medians for this segment
        segment_str = "_" + seg['id'] if seg['id'] != "" else ""
        cols_of_interest = []
        for m in metrics_config:
            bf_str = m.get('BF', None)
            if bf_str is not None:
                cols_of_interest.append(f"{m['name']}_{bf_str}{segment_str}")
            else:
                cols_of_interest.append(f"{m['name']}{segment_str}")
        available_cols = [c for c in cols_of_interest if c in df.columns]
        if not available_cols: continue
        medians = df.groupby(["input_snr", "method"])[available_cols].median()
        
        for method in methods:
            row_str = f"{method_labels.get(method, method)} & & "
            for i, snr in enumerate(snr_levels):
                if (snr, method) in medians.index and not (not CBW_method_for_3_sources and segment_info['id'] == "A3" and method == "CBW"):
                    for m_idx, metric in enumerate(metrics_config):
                        bf_str = metric.get('BF', None)
                        if bf_str is not None:
                            col_name = f"{metric['name']}_{bf_str}{segment_str}"
                        else:
                            col_name = f"{metric['name']}{segment_str}"
                        is_best_min = metric.get('is_min_better', True)
                        dec = metric.get('precision', 1)
                        unit = metric.get('unit', '')
                        
                        # Handle special cases (Oracle, GSS)
                        if method == "GSS" and metric.get('exclude_oracle_gss'): val_str = "-"
                        elif method == "Oracle" and metric.get('exclude_oracle_gss'): val_str = f"$\\SI{{0.0}}{{ {unit} }}$"
                        else:
                            val = medians.loc[(snr, method), col_name]
                            if pd.isna(val): val_str = "-"
                            else:
                                # Best finding logic
                                comp_methods = [m for m in methods if m != "Oracle"]
                                if metric.get('exclude_oracle_gss'): comp_methods = [m for m in comp_methods if m != "GSS"]
                                if not CBW_method_for_3_sources and segment_info['id'] == "A3":
                                    comp_methods = [m for m in comp_methods if m != "CBW"]
                                
                                is_best = False
                                if comp_methods and method != "Oracle":
                                    vals = medians.loc[snr, col_name].reindex(comp_methods).dropna()
                                    if not vals.empty:
                                        best_v = vals.min() if is_best_min else vals.max()
                                        is_best = (val <= best_v + 1e-6) if is_best_min else (val >= best_v - 1e-6)
                                
                                # Format value based on precision type
                                dec_val = metric.get('precision', 1)
                                if isinstance(dec_val, float):
                                    fmt_dec = len(str(dec_val).split('.')[-1]) if '.' in str(dec_val) else 0
                                else:
                                    fmt_dec = dec_val
                                    
                                fmt_val = f"{val:.{fmt_dec}f}"
                                if unit: val_str_base = f"$\\SI{{{fmt_val}}}{{{unit}}}$"
                                else: val_str_base = fmt_val
                                
                                val_str = f"\\textbf{{{val_str_base}}}" if is_best else val_str_base
                                
                        row_str += val_str + (" & " if m_idx < len(metrics_config)-1 else "")
                else:
                    row_str += " - & " * (len(metrics_config)-1) + " - "
                    
                if i < len(snr_levels) - 1: row_str += " & & "
            latex_str += row_str + r" \\" + "\n"
            
    # Finalize Table
    latex_str += r"\bottomrule" + "\n\\end{tabular}\n\\vspace{0.1cm}\n"
    latex_str += f"\\caption{{{caption}}}\n\\label{{tab:combined_{sadname}}}\n\\end{{table*}}\n"
    
    # Save
    if not isinstance(output_files, list): output_files = [output_files]
    for out_file in output_files:
        tex_path = Path(out_file).with_suffix(".tex")
        with open(tex_path, "w") as f: f.write(latex_str)


# ==============================================================================
# 2. USER CONFIGURATION BLOCK
# ==============================================================================

# Data
# Expected variables from above cells: dfs (dictionary of dataframes), method_names_short
EXPERIMENTS = ["OracleSAD", "COSAD"]
ALL_METHODS = [
  # "online-cgmm-mvdr",
#   "GSS",
#   "C",
#   "CSn",
#   "CWn",
#   "CSu",
  "CWu",
  "CBW",
#   "BOP", 
#   "BOP-S", 
#   "BOP-W", 
#   "BOPO", 
#   "BOPO-S", 
#   "BOPO-W",
#   "CB",
#   "CB-S",
  "CW-B",
  "Oracle", 
]

CBW_METHOD_FOR_3_SOURCES = False

GROUP_BY = "input_snr"
XLABEL = "Input SNR [dB]"
SNR_LEVELS = [0, 5, 10, 15]



# -----------------
# Define Plot Columns (Segments)
# -----------------
SEGMENTS = [
    # {"id": "A1", "title": "1 source"},
    {"id": "A2", "title": "2 sources"},
    {"id": "A3", "title": "3 sources"},
    # {"id": "D1", "title": "1 source deact"},
    # {"id": "D2", "title": "2 sources deact"},    
    # {"id": "", "title": "all"},
]

# -----------------
# Define Plot Rows (Metrics for Tables & Figures)
# -----------------
BF = 'LCMV'
METRICS = [
    {
        "name": "WMHA", 
        "ylabel": r"Weighted Hermitian Angle $\psi$ [°]", 
        "title": "RTF Estimation Accuracy",
        "latex_header": r"$\psi\downarrow$",
        "unit": r"\degree",
        "precision": 5.0,
        "is_min_better": True,
        "exclude_oracle_gss": True # Specific to WMHA logic
    },
    {
        "name": "DSINR", 
        "ylabel": r"SINR Improvement $\Delta\text{SINR}$ [dB]", 
        "title": "Source Extraction Performance",
        "latex_header": r"$\Delta$\gls{SINR}$\uparrow$",
        "unit": r"\dB",
        "precision": 0,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "PESQo", 
    #     "ylabel": r"$\text{PESQ}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\gls{PESQ}$",
    #     "unit": r"",
    #     "precision": 1,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    # {
    #     "name": "DFWSSNR", 
    #     "ylabel": r"FWSSNR Improvement $\Delta\text{FWSSNR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{FWSSNR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },    
    # {
    #     "name": "DSISDR", 
    #     "ylabel": r"SISDR Improvement $\Delta\text{SISDR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{SISDR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    {
        "name": "DSDR", 
        "ylabel": r"SDR Improvement $\Delta\text{SDR}$ [dB]", 
        "title": "Source Extraction Performance",
        "latex_header": r"$\Delta$\gls{SDR}$\uparrow$",
        "unit": r"\dB",
        "precision": 0.1,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "DHGSDR", 
    #     "ylabel": r"HGSDR Improvement $\Delta\text{HGSDR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{HGSDR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    # {
    #     "name": "DSTOI", 
    #     "ylabel": r"$\text{STOI}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\gls{STOI}$",
    #     "unit": r"",
    #     "precision": 2,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    {
        "name": "STOIo", 
        "ylabel": r"$\text{STOI}$", 
        "title": "Source Extraction Performance",
        "latex_header": r"$\gls{STOI}$",
        "unit": r"",
        "precision": 2,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "DPESQ", 
    #     "ylabel": r"PESQ Improvement $\Delta\text{PESQ}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{PESQ}$\uparrow$",
    #     "unit": r"",
    #     "precision": 1,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False
    # },
]

# Style Settings
FIG_DIMENSIONS = setup_matplotlib_rc(n_metrics=len(METRICS), n_segments=len(SEGMENTS))
FORCE_Y_LIMITS = {
    # Optional manual limits: "DSINR": (0.4, 0.9)
}

# -----------------
# LaTeX Mappings & Captions
# -----------------
LATEX_LABELS = {
    "GSS": r"\gls{GSS}~\cite{horiguchi2021blockonlinegss}",
    "C": r"\gls{C}", "CSn": r"\gls{CSn}~\cite{markovich-golan_performance_2018}",
    "CWn": r"\gls{CWn}~\cite{markovich-golan_performance_2018}", "CSu": r"\gls{CSu}~\cite{markovich-golan_performance_2018}",
    "CWu": r"\gls{CWu}~\cite{markovich-golan_performance_2018}",
    "BOP": r"\gls{BOP}~\cite{cherkassky_successive_2020}", "BOP-S": r"\gls{BOP-S}*", "BOP-W": r"\gls{BOP-W}*",
    "BOPO": r"\gls{BOPO}*", "BOPO-S": r"\gls{BOPO-S}*", "BOPO-W": r"\gls{BOPO-W}*",
    "CB": r"\gls{CB}*", "CB-S": r"\gls{CB-S}*", "CW-B": r"\gls{CW-B}*", "CBW": r"\gls{CBW}~\cite{gode2023covariance}",
    "Oracle": r"Oracle"
}

CAPTIONS = {
    "OracleSAD": r"Median weighted Hermitian angle $\psi$ for the conventional and proposed \gls{RTF} vector estimation methods and median \gls{SINR} improvement for all considered methods for different \glspl{SNR} assuming oracle source activity knowledge.",
    "COSAD": r"Median weighted Hermitian angle $\psi$ and \gls{SINR} improvement for the conventional and proposed \gls{RTF} vector estimation methods for different \glspl{SNR} using the online source counting method~\cite{gode2026dnnbased}."
}


# ==============================================================================
# 3. EXECUTION
# ==============================================================================

# Output configuration
BASE_PLOT_FILENAME = "Main_Exp_J2_BTEonly_Data_23_sources_20260610"
# BASE_PLOT_FILENAME = "Main_Exp_J2_BTEonly_Data_23_sources_20260610_deactSAD"

PAPER_PLOT_DIR = Path("/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/Springer_version/sn-article-template/figures/Plots/revision_caused_by_J1_reviews")

EXPERIMENTS = ["OracleSAD", "COSAD"]
# EXPERIMENTS = ["COSAD"] 

for sadname in EXPERIMENTS:
    print(f"Generating Plots & Tables for {sadname}...")
    df_eval = dfs[sadname].reset_index(drop=True)

    # Setup paths
    fname = f"{BASE_PLOT_FILENAME}_{sadname}_2.pdf"
    path_local = resultsdirs[sadname] / "plots" / "J2_Generic" / fname
    path_paper = PAPER_PLOT_DIR / fname
    
    path_local.parent.mkdir(parents=True, exist_ok=True)
    path_paper.parent.mkdir(parents=True, exist_ok=True)
    output_files = [path_local, path_paper]

    # Generate Grid Figure
    plot_generic_grid(
        df=df_eval,
        metrics_config=METRICS,
        segments_config=SEGMENTS,
        group_by=GROUP_BY,
        xlabel_text=XLABEL,
        output_files=output_files,
        all_methods=ALL_METHODS,
        is_cosad=(sadname == "COSAD"),
        fig_dims=FIG_DIMENSIONS,
        force_y_limits=FORCE_Y_LIMITS,
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
    
    # Generate Table
    generate_generic_latex_table(
        df=df_eval,
        sadname=sadname,
        metrics_config=METRICS,
        segments_config=SEGMENTS,
        all_methods=ALL_METHODS,
        method_labels=LATEX_LABELS,
        snr_levels=SNR_LEVELS,
        output_files=output_files,
        caption=CAPTIONS[sadname],
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
    print(f"-> Finished {sadname}. Saved to {path_local.parent}\n")
# Out:
# Generating Plots & Tables for OracleSAD...
# -> Finished OracleSAD. Saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/plots/J2_Generic
#
# Generating Plots & Tables for COSAD...
# -> Finished COSAD. Saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/plots/J2_Generic

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np
from pathlib import Path
import string

# ==============================================================================
# 1. CORE FUNCTIONS (Generic Logic)
# ==============================================================================

def setup_matplotlib_rc(n_metrics, n_segments, figure_width_pt=372.0, latex_font_size_pt=6.0):
    inches_per_pt = 1.0 / 72
    fig_width_in = figure_width_pt * inches_per_pt
    golden_ratio = (5**0.5 - 1) / 2
    
    # Each individual subplot should have a golden ratio.
    # Therefore the overall height ratio is height_ratio * (rows / cols)
    fig_height_in = fig_width_in * golden_ratio * (n_metrics / n_segments)

    mpl.use("pgf")
    mpl.rcParams.update({
        "pgf.texsystem": "pdflatex",
        'font.family': 'serif',
        'text.usetex': True,
        'pgf.rcfonts': False,
        'pgf.preamble': r'\usepackage{amsmath,graphicx,siunitx,bm}',
        'font.size': latex_font_size_pt,
        'axes.labelsize': latex_font_size_pt,      
        'axes.titlesize': latex_font_size_pt,      
        'legend.fontsize': latex_font_size_pt, 
        'xtick.labelsize': latex_font_size_pt, 
        'ytick.labelsize': latex_font_size_pt,
        'figure.figsize': [fig_width_in, fig_height_in],
    })
    return fig_width_in, fig_height_in

def plot_generic_grid(
    df, 
    metrics_config, 
    segments_config, 
    group_by, 
    xlabel_text, 
    output_files, 
    all_methods, 
    is_cosad, 
    fig_dims, 
    force_y_limits=None,
    CBW_method_for_3_sources=False
    ):
    fig_width_in, fig_height_in = fig_dims
    n_rows = len(metrics_config)
    n_cols = len(segments_config)
    
    # Setup Colors
    palette_colors = sns.color_palette("colorblind", n_colors=len(all_methods))
    method_color_map = dict(zip(all_methods, palette_colors))
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(fig_width_in, fig_height_in), dpi=600, squeeze=False)
    letters = list(string.ascii_lowercase)
    
    # Store min/max limits for each row to synchronize y-axes
    row_limits = {r: [float('inf'), float('-inf')] for r in range(n_rows)}

    plot_idx = 0
    for r, metric_info in enumerate(metrics_config):
        for c, segment_info in enumerate(segments_config):
            ax = axes[r, c]
            segment_str = "_" + segment_info['id'] if segment_info['id'] != "" else ""
            bfstr = metric_info.get('BF', None)
            if bfstr is not None:
                metric_col = f"{metric_info['name']}_{bfstr}{segment_str}"
            else:
                metric_col = f"{metric_info['name']}{segment_str}"
            is_bottom = (r == n_rows - 1)
            
            # --- Filtering ---
            plot_df = df.copy()
            if is_cosad: plot_df = plot_df[plot_df["method"] != "GSS"]
            if metric_info.get('exclude_oracle_gss', False): 
                plot_df = plot_df[~plot_df["method"].isin(["GSS", "Oracle"])]
                
            if not CBW_method_for_3_sources and segment_info['id'] == "A3":
                plot_df = plot_df[plot_df["method"] != "CBW"]

            if plot_df.empty or metric_col not in plot_df.columns:
                ax.set_visible(False)
                continue

            current_methods = [m for m in all_methods if m in plot_df["method"].unique()]

            # --- Plotting ---
            sns.barplot(
                data=plot_df, x=group_by, y=metric_col,
                hue="method", hue_order=current_methods, palette=method_color_map,
                errorbar="se", estimator=pd.Series.median, ax=ax, linewidth=0.15,
            )
            
            # Record limits for this row
            medians = plot_df[plot_df['method'].isin(current_methods)].groupby([group_by, "method"])[metric_col].median()
            if not medians.empty:
                row_limits[r][0] = min(row_limits[r][0], medians.min())
            # row_limits[r][0] = min(row_limits[r][0], ax.get_ylim()[0])    
            row_limits[r][1] = max(row_limits[r][1], ax.get_ylim()[1])
            
            # --- Styling ---
            ax.grid(True, axis='y', linestyle='--', alpha=0.7, linewidth=0.5)
            ax.set_title(f"{metric_info['title']} ({segment_info['title']})", pad=3) 
            ax.set_ylabel(metric_info['ylabel'])
            
            if is_bottom: ax.set_xlabel(xlabel_text)
            else: ax.set_xlabel(""); ax.set_xticklabels([]) 
                
            ax.text(-0.06, 1.1, r"{(" + letters[plot_idx] + ")}", transform=ax.transAxes, va='top', ha='right')
            plot_idx += 1

            if ax.get_legend(): ax.get_legend().remove()

            # --- Master Legend (Top Left Plot) ---
            if r == 0 and c == 0:
                handles = []
                for m in all_methods:
                    if is_cosad and m in ["GSS", "Oracle"]:
                        handles.append(mpatches.Patch(color="none", label="", alpha=0))
                    else:
                        handles.append(mpatches.Patch(color=method_color_map[m], label=m))
                ax.legend(handles=handles, loc='upper right', ncol=4, frameon=True, 
                          columnspacing=0.5, handletextpad=0.2, labelspacing=0.2)

    # --- Synchronize Y-Axes per row ---
    for r, metric_info in enumerate(metrics_config):
        # Allow precision to be either a float (e.g., 0.1, 0.01) or an int representing decimal places
        precision_val = metric_info.get('precision', 1)
        
        if isinstance(precision_val, float):
            precision_step = precision_val
            # Calculate format string precision based on step
            fmt_dec = len(str(precision_step).split('.')[-1]) if '.' in str(precision_step) else 0
        else:
            # Backwards compatibility: if precision is int (e.g. 1 means 0.1 step)
            precision_step = 10**(-precision_val)
            fmt_dec = precision_val
            
        # Floor based on precision step instead of just integer floor
        if row_limits[r][0] != float('inf'):
            # Multiply by 1/step, floor, then convert back
            factor = 1.0 / precision_step
            y_min = np.floor(row_limits[r][0] * factor) / factor #- precision_step
        else:
            y_min = 0
            
        y_max = row_limits[r][1]
        
        # Apply manual override if provided in config
        if force_y_limits and metric_info['name'] in force_y_limits:
            y_min, y_max = force_y_limits[metric_info['name']]

        for c in range(n_cols):
            axes[r, c].set_ylim(y_min, y_max)
            
            # Optionally format y-ticks according to precision
            axes[r, c].yaxis.set_major_formatter(mpl.ticker.FormatStrFormatter(f'%.{fmt_dec}f'))

    plt.tight_layout(pad=0.5, w_pad=1.5, h_pad=1.5)
    
    # Save
    if not isinstance(output_files, list): output_files = [output_files]
    for of in output_files:
        plt.savefig(of, bbox_inches='tight', pad_inches=0.02)
    plt.close()


def generate_generic_latex_table(df, sadname, metrics_config, segments_config, all_methods, method_labels, snr_levels, output_files, caption, CBW_method_for_3_sources=False):
    is_cosad = (sadname == "COSAD")
    methods = [m for m in all_methods if not (is_cosad and m in ["GSS", "Oracle"])]
    
    # Latex Header Construction
    num_cols = len(segments_config) * len(metrics_config) + len(segments_config) + 1
    header_align = "p{1.5cm}" + "c" * (num_cols - 1)
    
    latex_str = f"\\begin{{table*}}[htbp!]\n\\color{{black}}\n\\footnotesize\n\\centering\n\\begin{{tabular}}{{{header_align}}}\n\\toprule\n"
    latex_str += "\\multirow{3}{1.5cm}{\\\\\\textbf{Method}} & & \\multicolumn{" + str(num_cols - 2) + "}{c}{\\textbf{Sources}} \\\\\n"
    
    # Segment Headers (swapped with SNR headers)
    seg_row = "&"
    for seg in segments_config:
        seg_row += f" & \\multicolumn{{{len(metrics_config)}}}{{c}}{{{seg['title']}}} &"
    latex_str += seg_row[:-1] + "\\\\\n"
    
    # Line rules
    line_start = 3
    for i in range(len(segments_config)):
        latex_str += f"\\cmidrule{{{line_start}-{line_start+len(metrics_config)-1}}} "
        line_start += len(metrics_config) + 1
    latex_str += "\n"
    
    # Metric Headers
    metric_block = " & ".join([m['latex_header'] for m in metrics_config])
    latex_str += "& & " + " & & ".join([metric_block] * len(segments_config)) + " \\\\\n\\midrule\n"
    
    # Fetch all relevant columns
    cols_of_interest = []
    for seg in segments_config:
        segment_str = "_" + seg['id'] if seg['id'] != "" else ""
        for m in metrics_config:
            bf_str = m.get('BF', None)
            if bf_str is not None:
                cols_of_interest.append(f"{m['name']}_{bf_str}{segment_str}")
            else:
                cols_of_interest.append(f"{m['name']}{segment_str}")
    
    available_cols = [c for c in cols_of_interest if c in df.columns]
    
    if available_cols:
        medians = df.groupby(["input_snr", "method"])[available_cols].median()
    else:
        medians = pd.DataFrame()
    
    # --- Generate Rows per SNR ---
    for snr in snr_levels:
        latex_str += f"\\midrule\n\\multicolumn{{{num_cols}}}{{l}}{{\\textbf{{\\gls{{SNR}} = \\SI{{{snr}}}{{\\dB}}}}}} \\\\\n"
        
        for method in methods:
            row_str = f"{method_labels.get(method, method)} & & "
            for i, seg in enumerate(segments_config):
                segment_str = "_" + seg['id'] if seg['id'] != "" else ""
                
                if not medians.empty and (snr, method) in medians.index and not (not CBW_method_for_3_sources and seg['id'] == "A3" and method == "CBW"):
                    for m_idx, metric in enumerate(metrics_config):
                        bf_str = metric.get('BF', None)
                        if bf_str is not None:
                            col_name = f"{metric['name']}_{bf_str}{segment_str}"
                        else:
                            col_name = f"{metric['name']}{segment_str}"
                            
                        is_best_min = metric.get('is_min_better', True)
                        unit = metric.get('unit', '')
                        
                        # Handle special cases (Oracle, GSS)
                        if method == "GSS" and metric.get('exclude_oracle_gss'): val_str = "-"
                        elif method == "Oracle" and metric.get('exclude_oracle_gss'): val_str = f"$\\SI{{0.0}}{{ {unit} }}$"
                        else:
                            if col_name in medians.columns:
                                val = medians.loc[(snr, method), col_name]
                                if pd.isna(val): val_str = "-"
                                else:
                                    # Format value based on precision type
                                    dec_val = metric.get('precision', 1)
                                    if isinstance(dec_val, float):
                                        fmt_dec = len(str(dec_val).split('.')[-1]) if '.' in str(dec_val) else 0
                                    else:
                                        fmt_dec = dec_val
                                        
                                    fmt_val = f"{val:.{fmt_dec}f}"
                                    current_rounded = float(fmt_val)

                                    # Best finding logic
                                    comp_methods = [m for m in methods if m != "Oracle"]
                                    if metric.get('exclude_oracle_gss'): comp_methods = [m for m in comp_methods if m != "GSS"]
                                    if not CBW_method_for_3_sources and seg['id'] == "A3":
                                        comp_methods = [m for m in comp_methods if m != "CBW"]
                                    
                                    is_best = False
                                    if comp_methods and method != "Oracle":
                                        vals = medians.loc[snr, col_name].reindex(comp_methods).dropna()
                                        if not vals.empty:
                                            # Round all candidate values to the required decimal places for comparison
                                            rounded_vals = [float(f"{v:.{fmt_dec}f}") for v in vals]
                                            best_rounded_v = min(rounded_vals) if is_best_min else max(rounded_vals)
                                            is_best = (current_rounded == best_rounded_v)
                                    
                                    if unit: val_str_base = f"$\\SI{{{fmt_val}}}{{{unit}}}$"
                                    else: val_str_base = fmt_val
                                    
                                    val_str = f"\\textbf{{{val_str_base}}}" if is_best else val_str_base
                            else:
                                val_str = "-"
                                
                        row_str += val_str + (" & " if m_idx < len(metrics_config)-1 else "")
                else:
                    row_str += " - & " * (len(metrics_config)-1) + " - "
                    
                if i < len(segments_config) - 1: row_str += " & & "
            latex_str += row_str + r" \\" + "\n"
            
    # Finalize Table
    latex_str += r"\bottomrule" + "\n\\end{tabular}\n\\vspace{0.1cm}\n"
    latex_str += f"\\caption{{{caption}}}\n\\label{{tab:combined_{sadname}}}\n\\end{{table*}}\n"
    
    # Save
    if not isinstance(output_files, list): output_files = [output_files]
    for out_file in output_files:
        tex_path = Path(out_file).with_suffix(".tex")
        with open(tex_path, "w") as f: f.write(latex_str)
        
    return medians


# ==============================================================================
# 2. USER CONFIGURATION BLOCK
# ==============================================================================

# Data
# Expected variables from above cells: dfs (dictionary of dataframes), method_names_short
EXPERIMENTS = ["OracleSAD", "COSAD"]
ALL_METHODS = [
  # "online-cgmm-mvdr",
#   "GSS",
#   "C",
#   "CSn",
#   "CWn",
#   "CSu",
  "CWu",
  "CBW",
#   "BOP", 
#   "BOP-S", 
#   "BOP-W", 
#   "BOPO", 
#   "BOPO-S", 
#   "BOPO-W",
#   "CB",
#   "CB-S",
  "CW-B",
  "Oracle", 
]

CBW_METHOD_FOR_3_SOURCES = False

GROUP_BY = "input_snr"
XLABEL = "Input SNR [dB]"
SNR_LEVELS = [0, 5, 10, 15]



# -----------------
# Define Plot Columns (Segments)
# -----------------
SEGMENTS = [
    # {"id": "A1", "title": "1 source"},
    {"id": "A2", "title": "2 sources"},
    {"id": "A3", "title": "3 sources"},
    # {"id": "D1", "title": "1 source deact"},
    # {"id": "D2", "title": "2 sources deact"},    
    # {"id": "", "title": "all"},
]

# -----------------
# Define Plot Rows (Metrics for Tables & Figures)
# -----------------
BF = 'LCMV'
METRICS = [
    {
        "name": "WMHA", 
        "ylabel": r"Weighted Hermitian Angle $\psi$ [°]", 
        "title": "RTF Estimation Accuracy",
        "latex_header": r"$\psi\downarrow$",
        "unit": r"\degree",
        "precision": 5.0,
        "is_min_better": True,
        "exclude_oracle_gss": True # Specific to WMHA logic
    },
    {
        "name": "DSINR", 
        "ylabel": r"SINR Improvement $\Delta\text{SINR}$ [dB]", 
        "title": "Source Extraction Performance",
        "latex_header": r"$\Delta$\gls{SINR}$\uparrow$",
        "unit": r"\dB",
        "precision": 0.1,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "PESQo", 
    #     "ylabel": r"$\text{PESQ}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\gls{PESQ}$",
    #     "unit": r"",
    #     "precision": 1,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    # {
    #     "name": "DFWSSNR", 
    #     "ylabel": r"FWSSNR Improvement $\Delta\text{FWSSNR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{FWSSNR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },    
    # {
    #     "name": "DSISDR", 
    #     "ylabel": r"SISDR Improvement $\Delta\text{SISDR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{SISDR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    {
        "name": "DSDR", 
        "ylabel": r"SDR Improvement $\Delta\text{SDR}$ [dB]", 
        "title": "Source Extraction Performance",
        "latex_header": r"$\Delta$\gls{SDR}$\uparrow$",
        "unit": r"\dB",
        "precision": 0.1,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "DHGSDR", 
    #     "ylabel": r"HGSDR Improvement $\Delta\text{HGSDR}$ [dB]", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{HGSDR}$\uparrow$",
    #     "unit": r"\dB",
    #     "precision": 0,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    # {
    #     "name": "DSTOI", 
    #     "ylabel": r"$\text{STOI}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\gls{STOI}$",
    #     "unit": r"",
    #     "precision": 2,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False,
    #     "BF": BF,
    # },
    {
        "name": "STOIo", 
        "ylabel": r"$\text{STOI}$", 
        "title": "Source Extraction Performance",
        "latex_header": r"\gls{STOI}$\uparrow$",
        "unit": r"",
        "precision": 2,
        "is_min_better": False,
        "exclude_oracle_gss": False,
        "BF": BF,
    },
    # {
    #     "name": "DPESQ", 
    #     "ylabel": r"PESQ Improvement $\Delta\text{PESQ}$", 
    #     "title": "Source Extraction Performance",
    #     "latex_header": r"$\Delta$\gls{PESQ}$\uparrow$",
    #     "unit": r"",
    #     "precision": 1,
    #     "is_min_better": False,
    #     "exclude_oracle_gss": False
    # },
]

# Style Settings
FIG_DIMENSIONS = setup_matplotlib_rc(n_metrics=len(METRICS), n_segments=len(SEGMENTS))
FORCE_Y_LIMITS = {
    # Optional manual limits: "DSINR": (0.4, 0.9)
}

# -----------------
# LaTeX Mappings & Captions
# -----------------
LATEX_LABELS = {
    "GSS": r"\gls{GSS}~\cite{horiguchi2021blockonlinegss}",
    "C": r"\gls{C}", "CSn": r"\gls{CSn}~\cite{markovich-golan_performance_2018}",
    "CWn": r"\gls{CWn}~\cite{markovich-golan_performance_2018}", "CSu": r"\gls{CSu}~\cite{markovich-golan_performance_2018}",
    "CWu": r"\gls{CWu}~\cite{markovich-golan_performance_2018}",
    "BOP": r"\gls{BOP}~\cite{cherkassky_successive_2020}", "BOP-S": r"\gls{BOP-S}*", "BOP-W": r"\gls{BOP-W}*",
    "BOPO": r"\gls{BOPO}*", "BOPO-S": r"\gls{BOPO-S}*", "BOPO-W": r"\gls{BOPO-W}*",
    "CB": r"\gls{CB}*", "CB-S": r"\gls{CB-S}*", "CW-B": r"\gls{CW-B}*", "CBW": r"\gls{CBW}~\cite{gode2023covariance}",
    "Oracle": r"Oracle"
}

CAPTIONS = {
    "OracleSAD": r"Median weighted Hermitian angle $\psi$ for the conventional and proposed \gls{RTF} vector estimation methods and median \gls{SINR} improvement for all considered methods for different \glspl{SNR} assuming oracle source activity knowledge.",
    "COSAD": r"Median weighted Hermitian angle $\psi$ and \gls{SINR} improvement for the conventional and proposed \gls{RTF} vector estimation methods for different \glspl{SNR} using the online source counting method~\cite{gode2026dnnbased}."
}


# ==============================================================================
# 3. EXECUTION
# ==============================================================================

# Output configuration
BASE_PLOT_FILENAME = "Main_Exp_J2_BTEonly_Data_23_sources_20260610"
# BASE_PLOT_FILENAME = "Main_Exp_J2_BTEonly_Data_23_sources_20260610_deactSAD"

PAPER_PLOT_DIR = Path("/data4/Henri/j3/framewiseSpeakerCounting/documents/Journal2/Springer_version/sn-article-template/figures/Plots/revision_caused_by_J1_reviews")

EXPERIMENTS = ["OracleSAD", "COSAD"]
# EXPERIMENTS = ["COSAD"] 
medians = []
for sadname in EXPERIMENTS:
    print(f"Generating Plots & Tables for {sadname}...")
    df_eval = dfs[sadname].reset_index(drop=True)

    # Setup paths
    fname = f"{BASE_PLOT_FILENAME}_{sadname}_2.pdf"
    path_local = resultsdirs[sadname] / "plots" / "J2_Generic" / fname
    path_paper = PAPER_PLOT_DIR / fname
    
    path_local.parent.mkdir(parents=True, exist_ok=True)
    path_paper.parent.mkdir(parents=True, exist_ok=True)
    output_files = [path_local, path_paper]

    # Generate Grid Figure
    plot_generic_grid(
        df=df_eval,
        metrics_config=METRICS,
        segments_config=SEGMENTS,
        group_by=GROUP_BY,
        xlabel_text=XLABEL,
        output_files=output_files,
        all_methods=ALL_METHODS,
        is_cosad=(sadname == "COSAD"),
        fig_dims=FIG_DIMENSIONS,
        force_y_limits=FORCE_Y_LIMITS,
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
    
    # Generate Table
    med = generate_generic_latex_table(
        df=df_eval,
        sadname=sadname,
        metrics_config=METRICS,
        segments_config=SEGMENTS,
        all_methods=ALL_METHODS,
        method_labels=LATEX_LABELS,
        snr_levels=SNR_LEVELS,
        output_files=output_files,
        caption=CAPTIONS[sadname],
        CBW_method_for_3_sources=CBW_METHOD_FOR_3_SOURCES
    )
    
    medians.append(med)
    
    print(f"-> Finished {sadname}. Saved to {path_local.parent}\n")
# Out:
# Generating Plots & Tables for OracleSAD...
# -> Finished OracleSAD. Saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/oracle/plots/J2_Generic
#
# Generating Plots & Tables for COSAD...
# -> Finished COSAD. Saved to /data4/Henri/j3/framewiseSpeakerCounting/results/J2_RUN/J2_BXLS_main_exp/PrecomputedSAD/plots/J2_Generic

# %%
medians[1] - medians[0]
# Out:
#                    WMHA_A2  DSINR_LCMV_A2  DSDR_LCMV_A2  STOIo_LCMV_A2  \
# input_snr method
# 0         BOP     0.965385      -0.597515     -0.766021      -0.024852
#           BOPO-W  3.215741      -0.875407     -1.050281      -0.037452
#           CB      1.343423      -0.836663     -1.051880      -0.025284
#           CB-S    2.048336      -0.767554     -0.959968      -0.030950
#           CBW     1.331468      -0.744846     -0.896418      -0.010038
#           CW-B    3.102412      -0.976650     -1.139133      -0.041365
#           CWu     4.278087      -0.820098     -1.140021      -0.048426
#           Oracle       NaN            NaN           NaN            NaN
# 5         BOP     0.959362      -0.662720     -0.826231      -0.014723
#           BOPO-W  2.665627      -1.110443     -1.046346      -0.031366
#           CB      1.398011      -0.916324     -1.096735      -0.020168
#           CB-S    2.194890      -0.891892     -0.940021      -0.021455
#           CBW     1.925241      -1.004080     -1.216931      -0.014869
#           CW-B    2.634404      -0.997155     -1.060644      -0.031682
#           CWu     3.118112      -0.555066     -1.071417      -0.027269
#           Oracle       NaN            NaN           NaN            NaN
# 10        BOP     1.154828      -0.588293     -0.913116      -0.026014
#           BOPO-W  1.963807      -0.887442     -1.060631      -0.030309
#           CB      1.583784      -0.823575     -1.151573      -0.026510
#           CB-S    1.653739      -0.845447     -1.259830      -0.029025
#           CBW     2.250271      -1.209122     -1.547613      -0.016202
#           CW-B    2.321629      -0.843567     -1.124682      -0.030531
#           CWu     2.750789      -0.811602     -1.162336      -0.038415
#           Oracle       NaN            NaN           NaN            NaN
# 15        BOP     0.868489      -0.580636     -0.998556      -0.019393
#           BOPO-W  1.629922      -0.802872     -1.037188      -0.028683
#           CB      1.358272      -0.824587     -1.173678      -0.024202
#           CB-S    1.453589      -0.892664     -1.142897      -0.021329
#           CBW     1.931677      -1.931023     -1.731171      -0.014598
#           CW-B    1.626292      -0.764632     -1.180922      -0.029137
#           CWu     2.133019      -0.732486     -1.112481      -0.033097
#           Oracle       NaN            NaN           NaN            NaN
#
#                    WMHA_A3  DSINR_LCMV_A3  DSDR_LCMV_A3  STOIo_LCMV_A3
# input_snr method
# 0         BOP     1.901847      -1.263717     -1.122566      -0.031556
#           BOPO-W  2.403339      -0.885623     -0.727175      -0.026282
#           CB      2.679668      -1.208560     -1.165744      -0.030248
#           CB-S    2.517937      -0.751955     -0.600000      -0.024350
#           CBW    -4.765546      -0.444277     -0.017217      -0.010551
#           CW-B    2.644074      -0.744599     -0.665381      -0.032665
#           CWu     3.808206      -0.327466     -0.468664      -0.028897
#           Oracle       NaN            NaN           NaN            NaN
# 5         BOP     1.966674      -1.038939     -0.957971      -0.023141
#           BOPO-W  2.544410      -1.197387     -1.100721      -0.036745
#           CB      2.543018      -1.123103     -1.023885      -0.026618
#           CB-S    2.467917      -0.968944     -0.853651      -0.028173
#           CBW    -2.716134      -1.074825     -0.395152      -0.006919
#           CW-B    2.618779      -1.015998     -0.906698      -0.034129
#           CWu     3.405695      -0.232550     -0.578146      -0.029321
#           Oracle       NaN            NaN           NaN            NaN
# 10        BOP     1.731229      -1.323092     -1.152485      -0.024685
#           BOPO-W  2.178661      -1.467694     -1.242420      -0.035681
#           CB      2.149297      -1.236859     -1.162660      -0.033167
#           CB-S    1.962067      -1.137502     -1.068933      -0.035538
#           CBW    -1.216170      -0.595938     -0.291851      -0.010569
#           CW-B    2.212474      -1.270895     -1.126737      -0.039031
#           CWu     2.696364      -0.316947     -0.457456      -0.034108
#           Oracle       NaN            NaN           NaN            NaN
# 15        BOP     1.413233      -1.148247     -1.091721      -0.031687
#           BOPO-W  1.666280      -1.284415     -1.203893      -0.041049
#           CB      1.888339      -1.181788     -1.171753      -0.036551
#           CB-S    1.975847      -1.138518     -1.130027      -0.037840
#           CBW    -1.220712      -0.652289     -0.343920      -0.013291
#           CW-B    1.917331      -1.308943     -1.199161      -0.039840
#           CWu     2.310233      -0.355766     -0.511516      -0.033938
#           Oracle       NaN            NaN           NaN            NaN

# %%
diff_table_all = medians[1] - medians[0]
methods = ["CWu", "CBW", "CW-B", "Oracle"]
# select only rows corresponding to these methods
diff_table = diff_table_all.loc[(slice(None), methods), :]

# now please compute and print the minimum and maximum value per column in this diff_table
min_values = diff_table.min()
max_values = diff_table.max()

print("Minimum values per column:")
print(min_values)
print("\nMaximum values per column:")
print(max_values)

print(diff_table)
# Out:
# Minimum values per column:
# WMHA_A2          1.331468
# DSINR_LCMV_A2   -1.931023
# DSDR_LCMV_A2    -1.731171
# STOIo_LCMV_A2   -0.048426
# WMHA_A3         -4.765546
# DSINR_LCMV_A3   -1.308943
# DSDR_LCMV_A3    -1.199161
# STOIo_LCMV_A3   -0.039840
# dtype: float64
#
# Maximum values per column:
# WMHA_A2          4.278087
# DSINR_LCMV_A2   -0.555066
# DSDR_LCMV_A2    -0.896418
# STOIo_LCMV_A2   -0.010038
# WMHA_A3          3.808206
# DSINR_LCMV_A3   -0.232550
# DSDR_LCMV_A3    -0.017217
# STOIo_LCMV_A3   -0.006919
# dtype: float64
#                    WMHA_A2  DSINR_LCMV_A2  DSDR_LCMV_A2  STOIo_LCMV_A2  \
# input_snr method
# 0         CWu     4.278087      -0.820098     -1.140021      -0.048426
# 5         CWu     3.118112      -0.555066     -1.071417      -0.027269
# 10        CWu     2.750789      -0.811602     -1.162336      -0.038415
# 15        CWu     2.133019      -0.732486     -1.112481      -0.033097
# 0         CBW     1.331468      -0.744846     -0.896418      -0.010038
# 5         CBW     1.925241      -1.004080     -1.216931      -0.014869
# 10        CBW     2.250271      -1.209122     -1.547613      -0.016202
# 15        CBW     1.931677      -1.931023     -1.731171      -0.014598
# 0         CW-B    3.102412      -0.976650     -1.139133      -0.041365
# 5         CW-B    2.634404      -0.997155     -1.060644      -0.031682
# 10        CW-B    2.321629      -0.843567     -1.124682      -0.030531
# 15        CW-B    1.626292      -0.764632     -1.180922      -0.029137
# 0         Oracle       NaN            NaN           NaN            NaN
# 5         Oracle       NaN            NaN           NaN            NaN
# 10        Oracle       NaN            NaN           NaN            NaN
# 15        Oracle       NaN            NaN           NaN            NaN
#
#                    WMHA_A3  DSINR_LCMV_A3  DSDR_LCMV_A3  STOIo_LCMV_A3
# input_snr method
# 0         CWu     3.808206      -0.327466     -0.468664      -0.028897
# 5         CWu     3.405695      -0.232550     -0.578146      -0.029321
# 10        CWu     2.696364      -0.316947     -0.457456      -0.034108
# 15        CWu     2.310233      -0.355766     -0.511516      -0.033938
# 0         CBW    -4.765546      -0.444277     -0.017217      -0.010551
# 5         CBW    -2.716134      -1.074825     -0.395152      -0.006919
# 10        CBW    -1.216170      -0.595938     -0.291851      -0.010569
# 15        CBW    -1.220712      -0.652289     -0.343920      -0.013291
# 0         CW-B    2.644074      -0.744599     -0.665381      -0.032665
# 5         CW-B    2.618779      -1.015998     -0.906698      -0.034129
# 10        CW-B    2.212474      -1.270895     -1.126737      -0.039031
# 15        CW-B    1.917331      -1.308943     -1.199161      -0.039840
# 0         Oracle       NaN            NaN           NaN            NaN
# 5         Oracle       NaN            NaN           NaN            NaN
# 10        Oracle       NaN            NaN           NaN            NaN
# 15        Oracle       NaN            NaN           NaN            NaN

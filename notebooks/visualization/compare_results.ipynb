# %%
only_activation_oracleSAD_table_str = """
Method
SNR
0 5 10 15
ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑
2 sources
GSS [34] - 2.0 dB - 2.1 dB - 2.6 dB - 3.0 dB
CWv [20] 20.1◦ 4.6 dB 16.6◦ 4.4 dB 14.3◦ 4.7 dB 12.9◦ 5.6 dB
BOP [31] 28.4◦ 4.1 dB 23.9◦ 4.5 dB 20.3◦ 5.0 dB 18.6◦ 5.4 dB
BOP-S* 26.6◦ 4.8 dB 22.1◦ 5.0 dB 19.0◦ 5.3 dB 17.9◦ 5.5 dB
BOP-W* 25.3◦ 5.2 dB 21.7◦ 5.3 dB 19.1◦ 5.1 dB 18.1◦ 5.3 dB
BOPO* 27.1◦ 4.6 dB 22.9◦ 5.4 dB 18.9◦ 6.0 dB 17.2◦ 6.4 dB
BOPO-S* 25.1◦ 5.4 dB 20.7◦ 6.0 dB 17.7◦ 6.3 dB 16.7◦ 6.5 dB
BOPO-W* 21.8◦ 5.8 dB 18.5◦ 6.4 dB 16.3◦ 6.4 dB 15.4◦ 6.6 dB
Oracle 0.0◦ 9.8 dB 0.0◦ 10.8 dB 0.0◦ 11.3 dB 0.0◦ 11.4 dB
3 sources
GSS [34] - 1.7 dB - 2.0 dB - 2.3 dB - 2.8 dB
CWv [20] 22.0◦ 3.3 dB 18.9◦ 3.1 dB 17.0◦ 3.2 dB 16.1◦ 3.4 dB
BOP [31] 28.7◦ 4.4 dB 25.3◦ 4.7 dB 22.7◦ 5.0 dB 21.7◦ 5.3 dB
BOP-S* 27.4◦ 4.3 dB 24.3◦ 4.7 dB 22.2◦ 5.1 dB 21.1◦ 5.4 dB
BOP-W* 26.7◦ 4.4 dB 24.0◦ 4.7 dB 22.2◦ 4.8 dB 21.6◦ 5.0 dB
BOPO* 27.9◦ 4.7 dB 24.3◦ 5.1 dB 21.5◦ 5.5 dB 20.7◦ 5.8 dB
BOPO-S* 26.3◦ 4.9 dB 23.0◦ 5.4 dB 20.9◦ 5.6 dB 20.2◦ 5.9 dB
BOPO-W* 24.5◦ 5.0 dB 21.6◦ 5.6 dB 20.0◦ 6.0 dB 19.3◦ 6.1 dB
Oracle 0.0◦ 8.7 dB 0.0◦ 9.7 dB 0.0◦ 10.2 dB 0.0◦ 10.5 dB
"""

only_activation_COSAD_table_str = """
Method
SNR
0 5 10 15
ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑ ψ ↓ ∆SINR↑
2 sources
CWv [20] 23.4◦ 3.9 dB 19.0◦ 3.9 dB 15.8◦ 4.2 dB 14.5◦ 5.1 dB
BOP [31] 28.9◦ 3.7 dB 24.8◦ 4.1 dB 20.8◦ 4.6 dB 19.4◦ 5.1 dB
BOP-S* 27.6◦ 4.3 dB 23.5◦ 4.5 dB 19.7◦ 4.8 dB 18.8◦ 5.3 dB
BOP-W* 26.4◦ 4.6 dB 23.1◦ 4.7 dB 19.9◦ 4.7 dB 18.8◦ 5.0 dB
BOPO* 28.5◦ 4.1 dB 23.9◦ 4.8 dB 20.1◦ 5.4 dB 18.2◦ 6.0 dB
BOPO-S* 26.5◦ 4.9 dB 22.1◦ 5.4 dB 18.9◦ 5.7 dB 17.8◦ 6.1 dB
BOPO-W* 24.0◦ 5.0 dB 20.4◦ 5.7 dB 17.5◦ 5.8 dB 16.6◦ 6.2 dB
3 sources
CWv [20] 25.3◦ 2.9 dB 21.5◦ 2.7 dB 19.3◦ 2.8 dB 18.2◦ 3.0 dB
BOP [31] 30.1◦ 3.8 dB 26.0◦ 4.2 dB 23.6◦ 4.6 dB 22.5◦ 4.9 dB
BOP-S* 28.9◦ 3.6 dB 25.1◦ 4.1 dB 23.0◦ 4.6 dB 22.0◦ 4.9 dB
BOP-W* 28.5◦ 3.8 dB 24.9◦ 4.1 dB 23.1◦ 4.4 dB 22.3◦ 4.6 dB
BOPO* 29.9◦ 4.0 dB 25.5◦ 4.5 dB 22.7◦ 5.0 dB 21.8◦ 5.3 dB
BOPO-S* 28.1◦ 4.2 dB 24.0◦ 4.8 dB 22.0◦ 5.1 dB 21.5◦ 5.4 dB
BOPO-W* 26.9◦ 4.2 dB 23.2◦ 5.1 dB 21.3◦ 5.4 dB 20.6◦ 5.6 dB
"""

deactivation_table_str = """
Method SNR
0 5 10 15
Oracle Source Activity
GSS [34] 3.1 dB 3.5 dB 4.1 dB 4.5 dB
CWv [20] 3.9 dB 3.7 dB 3.3 dB 3.5 dB
BOP [31] 4.0 dB 4.3 dB 4.5 dB 4.7 dB
BOP-S* 4.6 dB 4.6 dB 4.6 dB 4.7 dB
BOP-W* 5.1 dB 4.7 dB 4.5 dB 4.5 dB
BOPO* 4.0 dB 4.7 dB 5.2 dB 5.4 dB
BOPO-S* 5.1 dB 5.2 dB 5.4 dB 5.4 dB
BOPO-W* 5.7 dB 5.8 dB 5.7 dB 5.7 dB
Estimated Source Activity
CWv [20] 2.8 dB 2.0 dB 1.7 dB 1.6 dB
BOP [31] 3.2 dB 3.0 dB 2.7 dB 2.6 dB
BOP-S* 3.4 dB 2.9 dB 2.8 dB 2.7 dB
BOP-W* 3.6 dB 3.0 dB 2.6 dB 2.4 dB
BOPO* 3.2 dB 3.1 dB 3.1 dB 3.0 dB
BOPO-S* 3.7 dB 3.3 dB 3.0 dB 2.9 dB
BOPO-W* 3.7 dB 3.2 dB 3.0 dB 2.8 dB
"""

# %%
import pandas as pd
import numpy as np

# --- Data Definitions (SINR) ---
snrs = [0, 5, 10, 15]

# Activation - Oracle SAD
data_act_oracle_2src = pd.DataFrame({
    'GSS': [2.0, 2.1, 2.6, 3.0], 'CWv': [4.6, 4.4, 4.7, 5.6], 'BOP': [4.1, 4.5, 5.0, 5.4],
    'BOP-S': [4.8, 5.0, 5.3, 5.5], 'BOP-W': [5.2, 5.3, 5.1, 5.3], 'BOPO': [4.6, 5.4, 6.0, 6.4],
    'BOPO-S': [5.4, 6.0, 6.3, 6.5], 'BOPO-W': [5.8, 6.4, 6.4, 6.6]
}, index=snrs).T

data_act_oracle_3src = pd.DataFrame({
    'GSS': [1.7, 2.0, 2.3, 2.8], 'CWv': [3.3, 3.1, 3.2, 3.4], 'BOP': [4.4, 4.7, 5.0, 5.3],
    'BOP-S': [4.3, 4.7, 5.1, 5.4], 'BOP-W': [4.4, 4.7, 4.8, 5.0], 'BOPO': [4.7, 5.1, 5.5, 5.8],
    'BOPO-S': [4.9, 5.4, 5.6, 5.9], 'BOPO-W': [5.0, 5.6, 6.0, 6.1]
}, index=snrs).T

# Activation - COSAD
data_act_cosad_2src = pd.DataFrame({
    'CWv': [3.9, 3.9, 4.2, 5.1], 'BOP': [3.7, 4.1, 4.6, 5.1], 'BOP-S': [4.3, 4.5, 4.8, 5.3],
    'BOP-W': [4.6, 4.7, 4.7, 5.0], 'BOPO': [4.1, 4.8, 5.4, 6.0], 'BOPO-S': [4.9, 5.4, 5.7, 6.1],
    'BOPO-W': [5.0, 5.7, 5.8, 6.2]
}, index=snrs).T

data_act_cosad_3src = pd.DataFrame({
    'CWv': [2.9, 2.7, 2.8, 3.0], 'BOP': [3.8, 4.2, 4.6, 4.9], 'BOP-S': [3.6, 4.1, 4.6, 4.9],
    'BOP-W': [3.8, 4.1, 4.4, 4.6], 'BOPO': [4.0, 4.5, 5.0, 5.3], 'BOPO-S': [4.2, 4.8, 5.1, 5.4],
    'BOPO-W': [4.2, 5.1, 5.4, 5.6]
}, index=snrs).T

# Deactivation
data_deact_oracle = pd.DataFrame({
    'GSS': [3.1, 3.5, 4.1, 4.5], 'CWv': [3.9, 3.7, 3.3, 3.5], 'BOP': [4.0, 4.3, 4.5, 4.7],
    'BOP-S': [4.6, 4.6, 4.6, 4.7], 'BOP-W': [5.1, 4.7, 4.5, 4.5], 'BOPO': [4.0, 4.7, 5.2, 5.4],
    'BOPO-S': [5.1, 5.2, 5.4, 5.4], 'BOPO-W': [5.7, 5.8, 5.7, 5.7]
}, index=snrs).T

data_deact_cosad = pd.DataFrame({
    'CWv': [2.8, 2.0, 1.7, 1.6], 'BOP': [3.2, 3.0, 2.7, 2.6], 'BOP-S': [3.4, 2.9, 2.8, 2.7],
    'BOP-W': [3.6, 3.0, 2.6, 2.4], 'BOPO': [3.2, 3.1, 3.1, 3.0], 'BOPO-S': [3.7, 3.3, 3.0, 2.9],
    'BOPO-W': [3.7, 3.2, 3.0, 2.8]
}, index=snrs).T

# --- COMPARISON 1: Activation Only - Oracle vs COSAD ---
print("=== COMPARISON 1: Activation Only - Oracle vs COSAD (SINR Loss) ===")
print("Positive value means Oracle is better (Performance Loss with COSAD)\n")

for n_src, df_oracle, df_cosad in zip(['2 Sources', '3 Sources'], 
                                      [data_act_oracle_2src, data_act_oracle_3src], 
                                      [data_act_cosad_2src, data_act_cosad_3src]):
    # Compute Diff on common index
    common_idx = df_oracle.index.intersection(df_cosad.index)
    diff = df_oracle.loc[common_idx] - df_cosad.loc[common_idx]
    
    print(f"--- {n_src} ---")
    print(diff.to_string())
    print("\nStatistics (Diff across SNRs):")
    stats = pd.DataFrame({
        'Max Loss': diff.max(axis=1),
        'Mean Loss': diff.mean(axis=1),
        'Median Loss': diff.median(axis=1)
    })
    print(stats.to_string())
    print("-" * 60 + "\n")
# Out:
# === COMPARISON 1: Activation Only - Oracle vs COSAD (SINR Loss) ===
# Positive value means Oracle is better (Performance Loss with COSAD)
#
# --- 2 Sources ---
#          0    5    10   15
# CWv     0.7  0.5  0.5  0.5
# BOP     0.4  0.4  0.4  0.3
# BOP-S   0.5  0.5  0.5  0.2
# BOP-W   0.6  0.6  0.4  0.3
# BOPO    0.5  0.6  0.6  0.4
# BOPO-S  0.5  0.6  0.6  0.4
# BOPO-W  0.8  0.7  0.6  0.4
#
# Statistics (Diff across SNRs):
#         Max Loss  Mean Loss  Median Loss
# CWv          0.7      0.550         0.50
# BOP          0.4      0.375         0.40
# BOP-S        0.5      0.425         0.50
# BOP-W        0.6      0.475         0.50
# BOPO         0.6      0.525         0.55
# BOPO-S       0.6      0.525         0.55
# BOPO-W       0.8      0.625         0.65
# ------------------------------------------------------------
#
# --- 3 Sources ---
#          0    5    10   15
# CWv     0.4  0.4  0.4  0.4
# BOP     0.6  0.5  0.4  0.4
# BOP-S   0.7  0.6  0.5  0.5
# ...

# %%
# --- COMPARISON 2: Deactivation vs Activation Only ---
print("=== COMPARISON 2: Deactivation vs Activation Only (SINR Change) ===")
print("Positive value means Activation Only (Reference) is better. \n")

# To compare apples to apples, we compare Deactivation (Mixed sources) to Activation Only (Split 2/3 sources).
# We show the difference against both 2-source and 3-source Activation Only results.

comparisons = [
    ("Oracle SAD (Deact) vs Act Only (2src)", data_deact_oracle, data_act_oracle_2src),
    ("Oracle SAD (Deact) vs Act Only (3src)", data_deact_oracle, data_act_oracle_3src),
    ("COSAD (Deact) vs Act Only (COSAD 2src)", data_deact_cosad, data_act_cosad_2src),
    ("COSAD (Deact) vs Act Only (COSAD 3src)", data_deact_cosad, data_act_cosad_3src),
]

for label, df_deact, df_act in comparisons:
    common_idx = df_deact.index.intersection(df_act.index)
    diff = df_act.loc[common_idx] - df_deact.loc[common_idx]
    
    print(f"\n--- {label} ---")
    print("Difference (Act_Only - Deact_Exp) [Positive: Act Only is better]:")
    print(diff.to_string())
    
    print("\nStatistics (Diff across SNRs):")
    stats = pd.DataFrame({
        'Max Diff': diff.max(axis=1),
        'Mean Diff': diff.mean(axis=1),
        'Min Diff': diff.min(axis=1)
    })
    print(stats.to_string())
    print("." * 60)
# Out:
# === COMPARISON 2: Deactivation vs Activation Only (SINR Change) ===
# Positive value means Activation Only (Reference) is better.
#
#
# --- Oracle SAD (Deact) vs Act Only (2src) ---
# Difference (Act_Only - Deact_Exp) [Positive: Act Only is better]:
#          0    5    10   15
# GSS    -1.1 -1.4 -1.5 -1.5
# CWv     0.7  0.7  1.4  2.1
# BOP     0.1  0.2  0.5  0.7
# BOP-S   0.2  0.4  0.7  0.8
# BOP-W   0.1  0.6  0.6  0.8
# BOPO    0.6  0.7  0.8  1.0
# BOPO-S  0.3  0.8  0.9  1.1
# BOPO-W  0.1  0.6  0.7  0.9
#
# Statistics (Diff across SNRs):
#         Max Diff  Mean Diff  Min Diff
# GSS         -1.1     -1.375      -1.5
# CWv          2.1      1.225       0.7
# BOP          0.7      0.375       0.1
# BOP-S        0.8      0.525       0.2
# BOP-W        0.8      0.525       0.1
# BOPO         1.0      0.775       0.6
# BOPO-S       1.1      0.775       0.3
# BOPO-W       0.9      0.575       0.1
# ............................................................
#
# ...
